# %% [markdown]
# # Session 8
# ## Scraping 2 - Parsing
# *Snorre Ralund *

# %% [markdown]
# Yesterday I gave you some powerful tricks. Tricks that will work when the data is already shipped in a neat format. However this is not the rule. Today we shall learn the art of parsing unstructured text and a more principled and advanced method of parsing HTML.
#
# This will help you build ***custom datasets*** within just a few hours or days work, that would have taken ***months*** to curate and clean manually.

# %% [markdown]
# ## Agenda
# **Parsing and cleaning raw data**
#
# HTML
# * Understanding the basics of HTML syntax.
# * Traversing and Navigating HTML trees using BeautifulSoup. Examples include:
#     * Extracting Text from HTML,
#     * Extracting Tables,
#     * Parsing of "unknown" structures.
# _________________________
# Raw Text
# * Learning the of Regular Expressions for extracting patterns in strings.
#     * Very valuable when cleaning and validating data, and for information extraction from raw text.
#
# _________________________

# %% [markdown]
# # Sidestep: Interactions and Automated Browsing
# Sometimes scraping tasks demand interactions (e.g. login, scrolling, clicking), and a no XHR data can be found easily, so you need the browser to execute the scripts before you can get the data.
#
# Here we use the `Selenium` package in combination with the `geckodriver` - download the latest release [here](download the latest geckodriver here: https://github.com/mozilla/geckodriver/releases). It allows you to animate a browser. I won't go into detail here, but just wanted to mention it.
#
# Installation (and maintainance of compatability) can be a little tough, but instead of trawling through crazy stackoverflow threads about your Issue, my experience tells me that downloaded the latest release, and installing the latest selenium version is always the cure.

# %%
from selenium import webdriver
## download the latest geckodriver here: https://github.com/mozilla/geckodriver/releases
path2gecko = 'C:/Users/jbv933/Downloads/geckodriver-v0.21.0-win64/geckodriver.exe' # define path to your geckodriver
browser = webdriver.Firefox(executable_path=path2gecko) # start the browser with a path to the geckodriver.
browser.get('https://www.google.com') # opens a webpage using the browser objects get method.

# %% [markdown]
# ## The HTML Tree
# HTML has a Tree structure.
#
# Each node in the tree has:
#         - Children, siblings, parents - descendants.
#         - Ids and attributes
#
# <img src="http://www.openbookproject.net/tutorials/getdown/css/images/lesson4/HTMLDOMTree.png"/>

# %% [markdown]
# ## Important syntax and patterns
# _______________
# ```html
# <p>The p tag indicates a paragraph <p/>
# ```
# _______________
# ```html
# <b>The b tag makes the text bold, giving us a clue to its importance <b/>
# ```
# output: <b>The b tag makes the text bold, giving us a clue to its importance <b/>
# ___________
# ```html
# <h1>h1</h1><h2>h2</h2><h2>h3</h3><b>Headers give similar clues</b>
# ```
# output:
# <h1>h1</h1><h2>h2</h2><h3>h3</h3><b>Headers give similar clues</b>
# _________________
# ```html
# <a href="www.google.com">The a tag creates a hyperlink <a/>
# ```
# output: <a href="www.google.com">The a tag creates a hyperlink <a/>
# _____________
# Finally you have the terrible and confusing iframe:
# ```html
#  <iframe src="https://www.google.com"></iframe>
# ```
# _________________

# %% [markdown]
# ## How do we find our way around this tree?
# * extracting string patterns using .split and regular expresssions as we did yesterday.
# * Specifying paths using css-selectors,xpath syntax.
# * A more powerful and principled (+readable) way is to use the ```python``` module ```BeautifulSoup``` to parse and traverse the tree.

# %% [markdown]
# ### Selectors
# Define a unique path to an element in the HTML tree.
# - quick but has to be hardcoded and also more likely to break.

# %%
# selenium example
browser.get('https://www.facebook.com')
# find login button.

# define username

# define password

# click on the submit button

# %% [markdown]
# ## Parsing HTML with BeautifulSoup
# BeautifulSoup makes the html tree navigable.
# It allows you to:
#     * Search for elements by tag name and/or by attribute.
#     * Iterate through them, go up, sideways or down the tree.
#     * Furthermore it helps you with standard tasks such as extracting raw text from html,
#     which would be a very tedious task if you had to hardcode it using `.split` commands and using your own regular expressions will be unstable.

# %%
# scraping newspaper articles example.
import requests
url = 'https://www.theguardian.com/us-news/2018/aug/10/omarosa-trump-book-the-apprentice-memoir'
response = requests.get(url)
html = response.text
from bs4 import BeautifulSoup

# %%
soup = BeautifulSoup(html,'lxml') # parse the raw html using BeautifoulSoup

# %%
# extract hyperlinks
links = soup.find_all('a') # find all a tags -connoting a hyperlink.
[link['href'] for link in links if link.has_attr('href')][0:5] # unpack the hyperlink from the a nodes.
# Out:
# ['#maincontent',
#  'https://www.theguardian.com/preference/edition/int',
#  'https://www.theguardian.com/preference/edition/uk',
#  'https://www.theguardian.com/preference/edition/us',
#  'https://www.theguardian.com/preference/edition/au']

# %%
headline = soup.find('h1') # search for the first headline: h1 tag. 
name = headline['class'][0].strip() # use the class attribute name as column name.
value = headline.text.strip() # extract text using build in method.
print(name,':',value)
# Out:
# content__headline : Omarosa says Trump is a racist who uses N-word – and claims there is tape to prove it

# %%
article_text = soup.find('div',{'class':'content__article-body from-content-api js-article__body'}).text # find the content.

# %% [markdown]
# Say we are interested in how articles cite sources to back up their story i.e. their hyperlink behaviour within the article, and we want to see if the media has changed their behaviour.
#
# We know how to search for links. But the cool part is that we can search from anywhere in the HTML tree. This means that once we have located the article content node - as above - we can search from there. This results in hyperlinks used within the article text.

# %%
# find the article_content node
article_content = soup.find('div',{'class':'content__article-body from-content-api js-article__body'})
# find citations within the article content.
citations = article_content.find_all('a')

# %%
citation_links = [] # define container to the hyperlinks
for citation in citations: # iterate through each citation node
    if citation.has_attr('data-link-name'): # check if it has the right attribute
        if citation['data-link-name'] =='in body link': # and if the value of that attribute is correct
            #print(citation['href'])
            citation_links.append(citation['href']) #  add link to the container

# %% [markdown]
# ## Scraping without hardcoding every element to collect.
# ### Hands-on example: Continuing the Cryptomarket scrape.
# When scraping a large and diverse website or even crawling many different, it can be useful to design more generic parsing schemes, were you haven't seen all elements you want to keep before hand. In the following example I demonstrate a simple example of this.
#
# Imagine we wanted data on the Cryptomarkets:
# * Go to the front page of a [Cryptomarket page](https://coinmarketcap.com). Looking in the **>Network Monitor<** we find a XHR file (helping their search function) containing links to Cryptocoin. Now we have the link to each page we want to visit.
#
# Visit this example: http://coinmarketcap.com/currencies/ethereum/
#
# Yesterday we saw how to find the XHR file with the underlying data behind the Chart. Now we want all the metadata displayed.
#
# Using the inspector we find that the information we want is located by a node tagged with `ul` - *"unordered list"* tag - with the defining class attribute *'list-unstyled details-panel-item--links'*. And the information is located in the `li` tag *"list item"*.
#
# First we locate this node using the `find` method.

# %%
url = 'https://coinmarketcap.com/currencies/ethereum/' # define the example url
response = requests.get(url) # 
soup = BeautifulSoup(response.text,'lxml') # parse the HTML

# %%
list_node = soup.find('ul',{'class':'list-unstyled details-panel-item--links'}) # search for the ul node

# %% [markdown]
# Now starting from this list_node, we can search for each list item - li node, using the find_all method.

# %%
list_items = list_node.find_all('li') # search for all list elements children of the list_node

# %% [markdown]
# From this we extract the information. Without having to hardcode all extractions we exploit that each html node has a attribute ('title'). We can therefore just loop through each node, extracting the title attribute and the text. ***-- This furthermore allows us to scrape content we did not know was there.***
#
# We use the title as the key in the dictionary. The value we are interested in two things, either the *hyperlink*, or the the *text* on display.

# %%
d = {} # defining our container
for list_item in list_items:
    key = list_item.span['title'] # attributes of a node can be fetched with dictionary-like syntax.
    if list_item.a!=None: # check if the node has a hyperlink.
        value = list_item.a['href'] # list_item.a ==list_item.find('a') returns the first node found.
    else:
        value = list_item.text.strip()
    d[key] = value
d
# Out:
# {'Rank': 'Rank 2',
#  'Website': 'https://www.ethereum.org/',
#  'Announcement': 'https://bitcointalk.org/index.php?topic=428589.0',
#  'Explorer': 'https://etherchain.org/',
#  'Message Board': 'https://forum.ethereum.org/',
#  'Chat': 'https://gitter.im/orgs/ethereum/rooms',
#  'Source Code': 'https://github.com/ethereum',
#  'Tags': 'Coin\nMineable'}

# %%
d['Source Code'],d['Source Code'].split('/')[-1]
# Out:
# ('https://github.com/ethereum', 'ethereum')

# %% [markdown]
# # ERC example
# Imagine we wanted to analyze whether the European funding behaviour was biased towards certain countries and gender. We might decide to scrape who has received funding from the ERC.
#
# * First we figure find navigate the grant listings.
# * Next we figure out how to page these results.
# * And finally we want to grab the information.

# %%
import requests
url = 'https://erc.europa.eu/projects-figures/erc-funded-projects/results?items_per_page=100&f[0]=funding_scheme%3AConsolidator%20Grant%20(CoG)'
response = requests.get(url)

# %%
from bs4 import BeautifulSoup
import bs4
soup = BeautifulSoup(response.text,'lxml')

# %% [markdown]
# You can search for nodes through their Tag, attribute, or

# %%
result_list = soup.find('div',{'class':'view-content'}) # find elements using tag name and class attribute

# %%
for child in result_list.children:
    if type(child)==bs4.NavigableString:
        
        continue
    break

# %%
datapoint = {}
for child2 in child.children:
    if type(child2)==bs4.NavigableString:
        continue
    spans = child2.findAll('span')
    
    if len(spans)==2:
        key,value = spans
    else:
        key,value = [i for i in list(child2.find('span').children) if not type(i)==bs4.NavigableString]
    datapoint[key.text] = value.text
    # Finding unknown titles using the strong tag as a clue.
    strong = child2.findAll('strong')
    if len(strong)>0:
        for node in strong:
            key = node.text
            value = str(node.next.next)
            print(key,node.next,value)
    #break
# Out:
# Max ERC Funding Max ERC Funding
# 1 999 172 €
#
# Duration Duration
# Start date: 2014-04-01, End date: 2019-03-31

# %% [markdown]
# # Extracting patterns from Raw Text

# %% [markdown]
# of course you already now your basic string operations:
#
# `string.split
# string.strip
# string.replace`
#
# And sometimes this will be enough, but sometimes it is not.

# %% [markdown]
# # Regular Expressions
# ![](https://cdn-images-1.medium.com/max/800/0*j1f-EFL7TDtf6K0o.jpg)

# %% [markdown]
# Regex can be a little terrifying:
#
# `pattern = '(?:(?:\r\n)?[ \t])*(?:(?:(?:[^()<>@,;:\\".\[\] \000-\031]+(?:(?:(?:\r\n)?[ \t])+|\Z|(?=[\["()<>@,;:\\".\[\]]))|"(?:[^\"\r\\]|\\.|(?:(?:\r\n)?[ \t]))*"(?:(?:\r\n)?[ \t])*)(?:\.(?:(?:\r\n)?[ \t])*(?:[^()<>@,;:\\".\[\] \000-\031]+(?:(?:(?:\r\n)?[ \t])+|\Z|(?=[\["()<>@,;:\\".\[\]]))|"(?:[^\"\r\\]|\\.|(?:(?:\r\n)?[ \t]))*"(?:(?:\r\n)?[ \t])*))*@(?:(?:\r\n)?[ \t])*(?:[^()<>@,;:\\".\[\] \000-\031]+(?:(?:(?:\r\n)?[ \t])+|\Z|(?=[\["()<>@,;:\\".\[\]]))|\[([^\[\]\r\\]|\\.)*\](?:(?:\r\n)?[ \t])*)(?:\.(?:(?:\r\n)?[ \t])*(?:[^()<>@,;:\\".\[\] \000-\031]+(?:(?:(?:\r\n)?[ \t])+|\Z|(?=[\["()<>@,;:\\".\[\]]))|\[([^\[\]\r\\]|\\.)*\](?:(?:\r\n)?[ \t])*))*|(?:[^()<>@,;:\\".\[\] \000-\031]+(?:(?:(?:\r\n)?[ \t])+|\Z|(?=[\["()<>@,;:\\".\[\]]))|"(?:[^\"\r\\]|\\.|(?:(?:\r\n)?[ \t]))*"(?:(?:\r\n)?[ \t])*)*\<(?:(?:\r\n)?[ \t])*(?:@(?:[^()<>@,;:\\".\[\] \000-\031]+(?:(?:(?:\r\n)?[ \t])+|\Z|(?=[\["()<>@,;:\\".\[\]]))|\[([^\[\]\r\\]|\\.)*\](?:(?:\r\n)?[ \t])*)(?:\.(?:(?:\r\n)?[ \t])*(?:[^()<>@,;:\\".\[\] \000-\031]+(?:(?:(?:\r\n)?[ \t])+|\Z|(?=[\["()<>@,;:\\".\[\]]))|\[([^\[\]\r\\]|\\.)*\](?:(?:\r\n)?[ \t])*))*(?:,@(?:(?:\r\n)?[ \t])*(?:[^()<>@,;:\\".\[\] \000-\031]+(?:(?:(?:\r\n)?[ \t])+|\Z|(?=[\["()<>@,;:\\".\[\]]))|\[([^\[\]\r\\]|\\.)*\](?:(?:\r\n)?[ \t])*)(?:\.(?:(?:\r\n)?[ \t])*(?:[^()<>@,;:\\".\[\] \000-\031]+(?:(?:(?:\r\n)?[ \t])+|\Z|(?=[\["()<>@,;:\\".\[\]]))|\[([^\[\]\r\\]|\\.)*\](?:(?:\r\n)?[ \t])*))*)*:(?:(?:\r\n)?[ \t])*)?(?:[^()<>@,;:\\".\[\] \000-\031]+(?:(?:(?:\r\n)?[ \t])+|\Z|(?=[\["()<>@,;:\\".\[\]]))|"(?:[^\"\r\\]|\\.|(?:(?:\r\n)?[ \t]))*"(?:(?:\r\n)?[ \t])*)(?:\.(?:(?:\r\n)?[ \t])*(?:[^()<>@,;:\\".\[\] \000-\031]+(?:(?:(?:\r\n)?[ \t])+|\Z|(?=[\["()<>@,;:\\".\[\]]))|"(?:[^\"\r\\]|\\.|(?:(?:\r\n)?[ \t]))*"(?:(?:\r\n)?[ \t])*))*@(?:(?:\r\n)?[ \t])*(?:[^()<>@,;:\\".\[\] \000-\031]+(?:(?:(?:\r\n)?[ \t])+|\Z|(?=[\["()<>@,;:\\".\[\]]))|\[([^\[\]\r\\]|\\.)*\](?:(?:\r\n)?[ \t])*)(?:\.(?:(?:\r\n)?[ \t])*(?:[^()<>@,;:\\".\[\] \000-\031]+(?:(?:(?:\r\n)?[ \t])+|\Z|(?=[\["()<>@,;:\\".\[\]]))|\[([^\[\]\r\\]|\\.)*\](?:(?:\r\n)?[ \t])*))*\>(?:(?:\r\n)?[ \t])*)|(?:[^()<>@,;:\\".\[\] \000-\031]+(?:(?:(?:\r\n)?[ \t])+|\Z|(?=[\["()<>@,;:\\".\[\]]))|"(?:[^\"\r\\]|\\.|(?:(?:\r\n)?[ \t]))*"(?:(?:\r\n)?[ \t])*)*:(?:(?:\r\n)?[ \t])*(?:(?:(?:[^()<>@,;:\\".\[\] \000-\031]+(?:(?:(?:\r\n)?[ \t])+|\Z|(?=[\["()<>@,;:\\".\[\]]))|"(?:[^\"\r\\]|\\.|(?:(?:\r\n)?[ \t]))*"(?:(?:\r\n)?[ \t])*)(?:\.(?:(?:\r\n)?[ \t])*(?:[^()<>@,;:\\".\[\] \000-\031]+(?:(?:(?:\r\n)?[ \t])+|\Z|(?=[\["()<>@,;:\\".\[\]]))|"(?:[^\"\r\\]|\\.|(?:(?:\r\n)?[ \t]))*"(?:(?:\r\n)?[ \t])*))*@(?:(?:\r\n)?[ \t])*(?:[^()<>@,;:\\".\[\] \000-\031]+(?:(?:(?:\r\n)?[ \t])+|\Z|(?=[\["()<>@,;:\\".\[\]]))|\[([^\[\]\r\\]|\\.)*\](?:(?:\r\n)?[ \t])*)(?:\.(?:(?:\r\n)?[ \t])*(?:[^()<>@,;:\\".\[\] \000-\031]+(?:(?:(?:\r\n)?[ \t])+|\Z|(?=[\["()<>@,;:\\".\[\]]))|\[([^\[\]\r\\]|\\.)*\](?:(?:\r\n)?[ \t])*))*|(?:[^()<>@,;:\\".\[\] \000-\031]+(?:(?:(?:\r\n)?[ \t])+|\Z|(?=[\["()<>@,;:\\".\[\]]))|"(?:[^\"\r\\]|\\.|(?:(?:\r\n)?[ \t]))*"(?:(?:\r\n)?[ \t])*)*\<(?:(?:\r\n)?[ \t])*(?:@(?:[^()<>@,;:\\".\[\] \000-\031]+(?:(?:(?:\r\n)?[ \t])+|\Z|(?=[\["()<>@,;:\\".\[\]]))|\[([^\[\]\r\\]|\\.)*\](?:(?:\r\n)?[ \t])*)(?:\.(?:(?:\r\n)?[ \t])*(?:[^()<>@,;:\\".\[\] \000-\031]+(?:(?:(?:\r\n)?[ \t])+|\Z|(?=[\["()<>@,;:\\".\[\]]))|\[([^\[\]\r\\]|\\.)*\](?:(?:\r\n)?[ \t])*))*(?:,@(?:(?:\r\n)?[ \t])*(?:[^()<>@,;:\\".\[\] \000-\031]+(?:(?:(?:\r\n)?[ \t])+|\Z|(?=[\["()<>@,;:\\".\[\]]))|\[([^\[\]\r\\]|\\.)*\](?:(?:\r\n)?[ \t])*)(?:\.(?:(?:\r\n)?[ \t])*(?:[^()<>@,;:\\".\[\] \000-\031]+(?:(?:(?:\r\n)?[ \t])+|\Z|(?=[\["()<>@,;:\\".\[\]]))|\[([^\[\]\r\\]|\\.)*\](?:(?:\r\n)?[ \t])*))*)*:(?:(?:\r\n)?[ \t])*)?(?:[^()<>@,;:\\".\[\] \000-\031]+(?:(?:(?:\r\n)?[ \t])+|\Z|(?=[\["()<>@,;:\\".\[\]]))|"(?:[^\"\r\\]|\\.|(?:(?:\r\n)?[ \t]))*"(?:(?:\r\n)?[ \t])*)(?:\.(?:(?:\r\n)?[ \t])*(?:[^()<>@,;:\\".\[\] \000-\031]+(?:(?:(?:\r\n)?[ \t])+|\Z|(?=[\["()<>@,;:\\".\[\]]))|"(?:[^\"\r\\]|\\.|(?:(?:\r\n)?[ \t]))*"(?:(?:\r\n)?[ \t])*))*@(?:(?:\r\n)?[ \t])*(?:[^()<>@,;:\\".\[\] \000-\031]+(?:(?:(?:\r\n)?[ \t])+|\Z|(?=[\["()<>@,;:\\".\[\]]))|\[([^\[\]\r\\]|\\.)*\](?:(?:\r\n)?[ \t])*)(?:\.(?:(?:\r\n)?[ \t])*(?:[^()<>@,;:\\".\[\] \000-\031]+(?:(?:(?:\r\n)?[ \t])+|\Z|(?=[\["()<>@,;:\\".\[\]]))|\[([^\[\]\r\\]|\\.)*\](?:(?:\r\n)?[ \t])*))*\>(?:(?:\r\n)?[ \t])*)(?:,\s*(?:(?:[^()<>@,;:\\".\[\] \000-\031]+(?:(?:(?:\r\n)?[ \t])+|\Z|(?=[\["()<>@,;:\\".\[\]]))|"(?:[^\"\r\\]|\\.|(?:(?:\r\n)?[ \t]))*"(?:(?:\r\n)?[ \t])*)(?:\.(?:(?:\r\n)?[ \t])*(?:[^()<>@,;:\\".\[\] \000-\031]+(?:(?:(?:\r\n)?[ \t])+|\Z|(?=[\["()<>@,;:\\".\[\]]))|"(?:[^\"\r\\]|\\.|(?:(?:\r\n)?[ \t]))*"(?:(?:\r\n)?[ \t])*))*@(?:(?:\r\n)?[ \t])*(?:[^()<>@,;:\\".\[\] \000-\031]+(?:(?:(?:\r\n)?[ \t])+|\Z|(?=[\["()<>@,;:\\".\[\]]))|\[([^\[\]\r\\]|\\.)*\](?:(?:\r\n)?[ \t])*)(?:\.(?:(?:\r\n)?[ \t])*(?:[^()<>@,;:\\".\[\] \000-\031]+(?:(?:(?:\r\n)?[ \t])+|\Z|(?=[\["()<>@,;:\\".\[\]]))|\[([^\[\]\r\\]|\\.)*\](?:(?:\r\n)?[ \t])*))*|(?:[^()<>@,;:\\".\[\] \000-\031]+(?:(?:(?:\r\n)?[ \t])+|\Z|(?=[\["()<>@,;:\\".\[\]]))|"(?:[^\"\r\\]|\\.|(?:(?:\r\n)?[ \t]))*"(?:(?:\r\n)?[ \t])*)*\<(?:(?:\r\n)?[ \t])*(?:@(?:[^()<>@,;:\\".\[\] \000-\031]+(?:(?:(?:\r\n)?[ \t])+|\Z|(?=[\["()<>@,;:\\".\[\]]))|\[([^\[\]\r\\]|\\.)*\](?:(?:\r\n)?[ \t])*)(?:\.(?:(?:\r\n)?[ \t])*(?:[^()<>@,;:\\".\[\] \000-\031]+(?:(?:(?:\r\n)?[ \t])+|\Z|(?=[\["()<>@,;:\\".\[\]]))|\[([^\[\]\r\\]|\\.)*\](?:(?:\r\n)?[ \t])*))*(?:,@(?:(?:\r\n)?[ \t])*(?:[^()<>@,;:\\".\[\] \000-\031]+(?:(?:(?:\r\n)?[ \t])+|\Z|(?=[\["()<>@,;:\\".\[\]]))|\[([^\[\]\r\\]|\\.)*\](?:(?:\r\n)?[ \t])*)(?:\.(?:(?:\r\n)?[ \t])*(?:[^()<>@,;:\\".\[\] \000-\031]+(?:(?:(?:\r\n)?[ \t])+|\Z|(?=[\["()<>@,;:\\".\[\]]))|\[([^\[\]\r\\]|\\.)*\](?:(?:\r\n)?[ \t])*))*)*:(?:(?:\r\n)?[ \t])*)?(?:[^()<>@,;:\\".\[\] \000-\031]+(?:(?:(?:\r\n)?[ \t])+|\Z|(?=[\["()<>@,;:\\".\[\]]))|"(?:[^\"\r\\]|\\.|(?:(?:\r\n)?[ \t]))*"(?:(?:\r\n)?[ \t])*)(?:\.(?:(?:\r\n)?[ \t])*(?:[^()<>@,;:\\".\[\] \000-\031]+(?:(?:(?:\r\n)?[ \t])+|\Z|(?=[\["()<>@,;:\\".\[\]]))|"(?:[^\"\r\\]|\\.|(?:(?:\r\n)?[ \t]))*"(?:(?:\r\n)?[ \t])*))*@(?:(?:\r\n)?[ \t])*(?:[^()<>@,;:\\".\[\] \000-\031]+(?:(?:(?:\r\n)?[ \t])+|\Z|(?=[\["()<>@,;:\\".\[\]]))|\[([^\[\]\r\\]|\\.)*\](?:(?:\r\n)?[ \t])*)(?:\.(?:(?:\r\n)?[ \t])*(?:[^()<>@,;:\\".\[\] \000-\031]+(?:(?:(?:\r\n)?[ \t])+|\Z|(?=[\["()<>@,;:\\".\[\]]))|\[([^\[\]\r\\]|\\.)*\](?:(?:\r\n)?[ \t])*))*\>(?:(?:\r\n)?[ \t])*))*)?;\s*)'`

# %% [markdown]
# However creating regular expressions is also fun, fun as in Suduko, and it is extremely valuable when working with any kind of text: e.g. Automating otherwise tedious manual tasks when cleaning a data set, searching, extracting and substituting specific patterns.
#
# Examples could be:
# - Extract currency and amount from raw text: $ 20, 10.000 dollars 10,000 £
# - email addresses: here you want to design a pattern (as above), that captures only the uses of @ within an email.
# - urls. Here you are trying to define all the different ways of writing urls (https, http, no http).
# - Dates. Again many variations: 17th of June 2017, 06/17/17 or 17. June 17
# - addresses,
# - phone numbers: 8888888 or 88 88 88 88 or +45 88 88 88 88,
# - emojiies in text. Capturing all the different ways of expressing smiley faces with one regular expression.

# %% [markdown]
# ** Regular Expression syntax **
#
# Ressources:
# Best way to learn is to practice, and with interactive examples. Two good ressources are here:
# * Community and interactive playground [here](http://regexr.com/)
# * Interactive tutorial [here](https://regexone.com/)
# * or you can use your notebook.
#
# Lookup all special characters [here](https://www.regular-expressions.info/refquick.html)
#
# * \+ = 1 or more times  -- e.g. "a+" will match: "a", and "aaa"
# * \* = 0 or more times  -- e.g. "ba*" will match: "b", and "ba", and "baaa"
# * {3} = exactly three times --- e.g. "ba{3}" will match "baaa", but not "baa"
# * ? = once or none
# * \\ = escape character, used to find characters that has special meaning with regex: e.g. \+ \*
# * [] = allows you to define a set of characters
# * ^ = applied within a set, it becomes the inverse of the set defined. Applied outside a set it entails the beginning of a string. $ entails the end of a string.
# * . = any characters except line break
# * | = or statement. -- e.g. a|b means find characters a or b.
# * \d = digits
# * \D = any-non-digits.
# * \s = whitespace-separator
#
# Sequences
# * (?:) = Defines a Non-capturing group. -- e.g. "(?:abc)+", will match "abc" and "abcabcabc", but not "aabbcc"
# * (?=)	= Positive lookahead - only match a certain pattern if a certain pattern comes after it.
# * (?!)	= Negative lookahead - only match a certain pattern if **not** a certain pattern comes after it.
# * (?<=)	= Positive lookbehind - only match a certain pattern if a certain pattern precedes it.
# * (?<!) = Negative lookbehind - only match a certain pattern if **not** a certain pattern precedes it.

# %% [markdown]
# ## Regular expressions (2): define - inspect - refine
# You are trying to balance getting (and learning/exploring) all the different variations of e.g. an emojii. while also making sure not to include ordinary use of :.
#
# This means iterating through many steps, some expressions being too broad others being to narrow, and others not matching all that you need.
#
# I developed a small module for this that you can use. Just run the following piece of code to download, save and import the module.
#
# ```python
# # download module
# url = 'https://raw.githubusercontent.com/snorreralund/explore_regex/master/explore_regex.py'
# response = requests.get(url)
# # write script to your folder to create a locate module
# with open('explore_regex.py','w') as f:
#     f.write(response.text)
# # import local module
# import explore_regex as e_re
# ```

# %% [markdown]
# ## Lets do an example
# first we get a dataset to play with.
# We download the following link using pandas and dump it to your local machine using the `pd.to_csv()` method.

# %%
import pandas as pd
import re
path2data = 'https://raw.githubusercontent.com/snorreralund/scraping_seminar/master/danish_review_sample.csv'
df = pd.read_csv(path2data)
df.to_csv('danish_review_sample.csv',index=False)

digit_re = re.compile('[0-9]+') # compiled regular expression for matching digits
df['hasNumber'] = df.reviewBody.apply(lambda x: len(digit_re.findall(x))>0) # check if it has a number

# %%
# download module
import requests
url = 'https://raw.githubusercontent.com/snorreralund/explore_regex/master/explore_regex.py'
response = requests.get(url)
# write script to your folder to create a locate module
with open('explore_regex.py','w') as f:
    f.write(response.text)
# import local module
import explore_regex as e_re

# %%
sample_string = '\n'.join(df[df.hasNumber].sample(2000).reviewBody)
print (sample_string)
# Out:
# Jeg kan klart anbefale et kursusforløb på Kilden hvis du ønsker en personlig udvikling som flytter noget på et dybere plan.
# Jeg har gennem snart 2 år været en flittig kursist på uddannelsesstedet og har gennem denne tid haft - og får stadig personlige oplevelser og udfordringer som gør mig mere afklaret omkring hvem jeg i bund og grund er og hvad jeg ønsker mig med mit liv. Samtidig giver det mig en god indsigt i andre menneskers liv og hvordan de takler livets udfordringer som jeg har stor gavn af i mit fritidsjob som healingsmassør og samtale terapaut.
# Har nu haft Oister i mange &#229;r og aldrig haft et problem med dem &#128576;  Hver gang man bliver ringet op af en irriterende s&#230;lger fra et andet selskab kan jeg med et smil p&#229; l&#230;ben sige at de ikke kan f&#248;lge med Oister og jeg f&#229;r ret hver gang &#128540; Jeg har f&#229;et hele familien med p&#229; Oister og vi er en k&#230;mpe sammenbragt familie og alle er meget tilfredse og kan ikke finde noget bedre til prisen&#128515; Det eneste er data og telefoni i udlandet h&#229;ber der snart kommer et godt tilbud fra Oister med alt incl .
# Dette er et firma der kender til kundebehandling - varen bestilles og er leveret under 24 timer..man får information fra start til slut..sådan..
# Kan varmt anbefales at handle på Knager-Online.
# Det er lørdag, jeg bestiller varer for første gang.
# Kl 13:18 har jeg bekræftelse på min ordre- 45 min senere 14:05 er min ordre pakket færdig og bliver sendt😳
# Det er seriøs god service og arbejde, og det er stadig på en lørdag-flot👍🏻👍🏻
# Hurtig levering - fik varen 2 dage efter jeg bestilt. Super
# Jeg synes i bund og grund og det okay men jeg var meget mere fan da det hed post Danmark. Og jeg har altid brugt post Danmark ( nu vil jeg heller bruge gls eller andet når min pakke skal leveres!!).  Alt post og pakker er lang tid om af komme.  Man kan være hjemme en hel dag. Uden det har ringet på, og alligevel få en besked om af en pakke er prøvet leveret det for dårligt. Også synes jeg godt det kunne bliver af man ikke skal til den anden ende af byen for af hente sin pakke. Når man bor 1 minut væk for et andet pakke sted, hvor man også kan hente post nord pakker
# .
# Hurtig levering, korrekt vare - det kan ikke blive bedre
# 232268
# det er stort set i orden, man kan diskutere om prisen på mobiltelefoner om den er realistisk, men det er en mindre  detalje, det der tæller er om man kan stole på at man får den rigtige  vare, det har jeg oplevet ikke at få en gang, ud af 6 - 8 handler, men den tog de så tilbage og ellers er abonnementet i orden med flere muligheder afhængig af behov, og regningen er tilsyneladende også ok.
# Det er for dårligt at vores netto ikke har en eneste hp blækpatron farve og sort :(( jeg har været i 3 butik idag men der er ikke nogen der har noget:(( rigtig dårlig  så man kan ikke tro på deres tilbuds avis  frem over... Jeg ville handle hos andre og ikke hos netto frem over nu når man ikke tro på dem...
# Jeg købte en str. 41, som viste sig at være meget lille i størrelsen (hvilket ikke var beskrevet under varen), og da jeg så ville ombytte dem til str. 42, var denne ikke på lager, og jeg kom så selv til at betale for returfragten.
# Havde man beskrevet varen ordentligt til at starte med, havde jeg aldrig købt en str. 41, så det havde være rimeligt og god service at jeg fik lov til at returnere uden omkostninger.
# Dette var første og sidste gang jeg handlede hos eshoes.dk.
# Hurtig levering (1 dag) Ville dog ønske det var billigere!!!!!
# Bestilte varen via hjemmesiden og til trods for at der stod det ville tage 5 dage før pakken ville komme, så var den der allerede efter 3 dage.
# Har købt rigtig meget både i de fysiske butikker, såvel som via hjemmesiden. Har aldrig haft noget at udsætte på service eller levering. Kan kun give Elgiganten de bedste anbefalinger.
# 25% billigere end ALLE andre i hele landet på den konkrete model. Flinke og servicemindede, selv om jeg allerede havde bestemt mig pga prisen. Byttede "faste" dele af ordren til nye med pæne nedslag. Cyklen blev leveret den aftalte dag. Inden da var det fuld fleksibilitet, rådgivning med HOLDNINGER, og den perfekte kundeoplevelse
# Lynhurtig levering - mindre end 24 timer efter bestillingen - og god pris. Så bliver det ikke bedre
# hej jeg syntes der er lang leveringstid og jeg får mailen fra trustpilot og har ikke modtaget hverken Track & Trace eller vare der blev købt 1/5 og vi har den 9/5 i dag
# hilsen
# christian
# Jeg har brugt iRep 5-6 gange både gennem forsikring og direkte. De er søde og normalt tager en reparation et par timer og man kan hente igen.
# Alle reparationer har virket og jeg har ikke haft brug for at komme tilbage fordi det ikke virkede.
# Har flere gange været i Telia i Aalborg Storcenter. Selvom køen kan være lidt lang, og ventetiden lang, så er betjeningen god når det først bliver ens tur. :-) De prøver typisk at finde den løsning som er billigst for mig, uden at det går på kompromis med mine behov. Personalet er venligt og smilende, men får kun 4 stjerner pga. den lange vente- og betjenings tid.
# Har ventet i 2 uger på mit simkort som de skulle have sendt TO gange.. Hvor svært er det at sende et simkort? De vil åbentbart ikke have mig som kunde!
# Bestilte fiksegrej for 700kr og modtog som forventet det hele efter to dage.
# Jeg købte et Yepp cykelsæde hos Cykelpartner.dk
# Det var nemt og overskueligt at bestille, det billigste på markedet, samt det blev leveret dagen efter.
# Jeg er 100% tilfreds
# I sender 2-3 sms'er og mails pr. dag - og alligevel kan der gå 3-4 dage før I leverer. I de 3-4 dage får man flere sms'er om den er lastet
# Efter at jeg selv havde keglet i bestillingen fik jeg efterfølgende hjælp af kundeservice.
# Og her må man nok sige at der var tale om kundeservice. Sabrina eller var navnet Sabina? (undskyld) hjalp mig igennem ordrebestillingen med professionalisme, venlighed og smil i stemmen ;0)
# Dejligt tilbud om at man kan parkere gratis de første 14 dage,  så har man lige tid til at vende sig til at huske at tjekke ind og  ud.
# Igen rigtig dårlig service fra Bilka webshop.
# Nu er det sidste gang vi har handlet hos Bilka.
#
# Vi bestilte havemøbler i webshoppen, og valgte et tidspunkt for levering i dag melllem 11 & 15. Det blev den sidste ferie dag brugt på.
#
# Igår aftes fik vi en sms om at vi skulle være hjemme mellem 11 & 15, nice hvis man skulle have glemt det.
#
# Men i 1 time før levering kom der en mail om at det var 4 uger forsinket, HVADDDD det opdager man vel ikke 1 time før levering.
#
# Nu har vi spildt en fridag på at sidde og vente på Bilka. I går aftes kørte vi de gamle møbler på genbrugspladsen, så nu er der ingen  havemøbler de næste 4 uger.
#
# Det ligner den samme dårlige service vi fik ad vi købte en gamer labtop på bilka webshop.
#
# Så nu skal vi ikke bruge haven i 4 uger, og bruge endnu en fridag, hold da kæft en dårlig service igen fra Bilka.
#
# Når man så skriver lidt kritik til bilka, får man en stabdard mail om at det er ignoreret da det ikke med i bilka betingelser at man skriver kritisk om deres leveringer.
#
# Nå men det bliver helt sikkert sidste gang, og kan jo se her at vi er ikke alene om at få dårlig behandling.
#
# Man bør sgu kikke på tripadvisor inden man handler på nettet.
# Jeg bestilte en Proto-col Bronze hos Shytobuy til 299kr. Produktet jeg modtog var IKKE bronze, men derimod var det en boost, som kun koster 269kr. På min oversigt på netbank kunne jeg se, at der var blevet trukket penge for en Proto-col Bronze og naturligvis blev jeg utilfreds, MEN - senere bad Shytobuy mig om min mening om mit sidst-købte produkt og jeg fortalte selvfølgelig hvad der var sket. Marie fra kundeservice undskyldte mange gange for fejlen og bad mig sende et billede af produktet, hvorefter hun så ville sende mig en Proto-col Bronze på deres regning. Det må jeg nok sige, jeg er dybt imponeret og kan varmt anbefale alle at handle hos Shytobuy.dk
# Efter den behagelige behandling de har givet mig, føler jeg mig i hvert fald tryg ved at handle hos dem fremover.
# Venlig god hjælp via tlf. da det drejede sig om skaffedele tog det lige 2 dage inden jeg modtog det bestilte :-) hurtigere og bedre kan det vist ikke være. Handler gerne igen ved behov :-)
# Ved bestilling, påtalte jeg vigtigheden af 3dg. lev. tid.
# Fik varen på 2 dg. Fin service. I er bare hurtige.
# 1000 tak for Nicklas nr 106 som leverede super service 🇩🇰
# Jeg havde alligevel intet andet at lave lørdag eftermiddag end at vente i kø med 42!!!!!!! foran mig.
# Lækker oplevelse
# Håndterede klagesag udmærket og til tilfredhed for kunden. Men det tog dog lidt længere tid end nødvendigt, derfor kun 4 stjerner.
# Jeg bestilte en vare, som ifølge nettet var til rådighed i Hillerød afd.
# Varen var bestilt til afhentning i butikken, og dette var også blevet os bekræftet.
# Vi kører fra Stenløse til Hillerød og venter hos Elgigantens vareudlevering i 30 min. Da det bliver vores tur, bliver vi, efter yderligere ventetid, præsenteret for en tilsyneladende overordnet, der fortæller os at varen i mellemtiden var solgt, og det er hvad der kan ske, når man bestiller til afhentning, Da vi måbende, efter al vor spilte tid, tillader os at spørge ind til problemet, bliver vi bedt om at "tie stille", mens Elgigantens medarbejder kommer med den ene mærkværdige forklaring efter den anden. Det kunne vi ikke holde ud at høre på, så vi sagde pænt farvel, hvilket medarbejderen var fløjtende ligeglad med.
# Ikke een eneste beklagende kommentar vedr. vores unødvendige kørsel og ventetid samt ikke så meget som en besked forlods på mail eller sms om, at den bekræftede vare ikke længere kunne afhentes.
# Det er for dårligt Elgiganten!!!!
# God oplevelse - hvis man vil vente 3 måneder på ens ordre og dertil ingen opdateringer få eller kompensation eller blot en halvhjertet undskyldning.
# Varen var dog upåklagelig, da den efter 1/4 af et år kom frem.
# I April kontaktede en Telenor sælger mig for at sælge mig trådløst bredbånd.
# Da jeg stadig var bundet til Telia  i 8 måneder takkede jeg nej tak.
# Desuden har jeg ikke en bærebar computer.
# Han insisterede at jeg da kunne få det på prøve i 30 dage for 1 kr.
# Da jeg var lidt interesseret i Telenors sendestyrke tænkte jeg hvorfor ikke prøve.
# Andre familie medlemmer har bærebar og der hvor vi bor er der problemer med sendsestyrke generelt.
# Ingen teleselskaber holder hvad de lover der hvor vi bor.
#
# Men grundet extra arbejde i de 30 dage fik jeg hverken aktiveret eller testet produktet.
# Og der kommer en regning på 300 kr!
# Sælgeren ringer igen til mig for at høre om produktet virker.
# Jeg beklager jeg ikke har haft tid og brokker mig over regningen på 300 kr
# Han siger at det skal jeg ikke tage mig af og at jeg bare skal smide den i skraldespanden og huske at aflevere hardwaren næste gang jeg kommer forbi en Telenor butik.
# Jeg smider regningen ud og så kommer der en rykker.
# Den smider jeg også bare ud.
#
# Nu 4 måneder efter kommer der en rykker fra RKI på 3.946,25 kr.
# Jeg føler jeg er udsat for et direkte scam nummer.
#
# Har brugt timevis i telefon med telenor blevet sendt videre for til sidst at få at vide telenor ikke kan gøre noget.
#
# Update: 3 August 2011
#
# Telenor har undersøgt sagen, beklaget og trukket sagen tilbage fra inkasso. Det skal de alligevel lige have et plus for trods alt.
# Har opgraderet fra 1 til 2.
# Fik min pakke 1 dag efter jeg bestilte den og bestilte om aftnen
# Da jeg skulle have mit første jagtgevær blev jeg opfordret til at køre til østjysk våbenhandel, da dette skulle være et sted hvor der er styr på sagerne.
#
# Jeg kørte fra Sydfyn til butikken, hvor jeg troede jeg skulle gøre en god handel. Jeg var da også så heldig at de lige havde fået drømmegeværet i bytte.
# En beretta silver pigeon.
# Da jeg er ret ny i gamet, fik jeg hjælp af en assistent som kunne bekræfte at den lå godt til mig.
#
# Efter jeg kom hjem viste jeg geværet til en af mine jagtkammerrater som har mange års erfaring med jagt og våben.
# Han kunne hurtigt konkludere at det var et venstre hånds våben..
#
# Ringede til østjysk, og fik besked på at kører op med det. Da jeg kommer op i butikken konkludere de hurtigt det samme som min kammerat og tager geværet tilbage. Jeg spørg ekspedienten om man kan få en lille ting som kompensation for at have kørt de mange kilometer og stadigvæk er uden gevær, hvortil han små griner og siger at det kan han desværre ikke give mig!!!
#
# Mit råd til andre.. køb jeres geværer et andet sted med mindre i selv har 100% styr på det, for det har de ikke hos østjysk!!!
# Alt var fint - svære tilkørselsforhold som blev beskrevet ved bookning og efterfulgt 100% - desværre blev fomiddagslevering leveret kl. ca.14:00, - ellers super.
# At kunne stifte selskab, skal gerne gøres hurtigt og præcist - hvor alle regler overholdes. Derfor har vi valgt Nemadvokat som vi benytter som fast partner til vores klienter. Vi får gennemsnit stiftet  ca. 25-50 selskaber om året - og det er altid en fornøjelse.
# Jeg har prøvet at få laveret vin nat/aften. Tidligere har jeg været meget tilfreds, men i sidste uge gik det helt galt. Vinen blev først leveret efter 7 arbejdsdage. Det klagede jeg over, men fik blot besked på, at sådan var det og det kunne læses på Philipsons hjemmeside. Det er muligt, at der et eller andet sted står, at det kan tage 7 arbejdsdage, men jeg har altså ikke kunne finde det. Det synes jeg er dårlig kundeservice. Også omkring en anden leveringsform for visse postnumre kan man heller ikke umiddelbart se, HVAD det er for posatnumre, der kan benytte denne specielle leveringsform?
# Jeg har tidligere kontaktet Philipsen omkring levringer, men har altid modtaget et venligt og imødekommende svar. Men desværre ikke denne gang.
# Med venlig hilsen
# Jørn Rahbek Jensen
# Lindelunden 21, 6705 Esbjerg
# Bestilling kl. 13.30 den ene dag og næste dag kl.10 kom pakken. Det kan da ikke gøres hurtigere. Kan kun anbefales.
# Leveringstid var super. Bestilte fredag formiddag og levering var 7.30 mandag morgen. På firma adresse.
# Jeg købte 4 vouchers gennem My Deal til Foto.dk. 1 stk. til et lærredsprint på 60x80 eller 80x60 cm og 3 stk. til lærredsprint på 20x30 eller 30x20 cm.
#
# På grund af sygdom blev voucheren til lærredsprintet på 60x80 eller 80x60 cm ikke brugt inden udløb, så jeg kontaktede Foto.dk for at høre om det var muligt at forlænge den. Jeg fik beskeden: "Ingen stress - kampagnen er forlænget til den 15. april." Dvs. at kampagnen var forlænget for alle der havde købt en voucher.
#
# Den 15. april har jeg lavet mit billede færdig, et billede af en højtelsket hund der døde ganske uventet knap 2 år gammel, så det ville betyde meget at få dette lærredsprint lavet. Da jeg vil bestille lærredsprintet den 15. april duer voucheren ikke længere! Jeg kontakter derfor kundeservice, da jeg jo er blevet oplyst, at kampagnen var forlænget til den 15. april.
#
# De svarer: "Det er korrekt, at der var nogle koder, der udløb natten mellem lørdag og søndag. Jeg kan desværre ikke forlænge koden, men de penge du i sin tid for dealen er ikke tabt af den grund. Lidt senere i dag vil det beløb du betalte blive sat ind på din foto.dk-konto. Det beløb kan du efterfølgende anvende på et vilkårligt produkt på vores hjemmeside. Jeg kan som nævnt ikke forlænge koden, men jeg kan give dig en ny, der giver dig 50% rabat på dit billede. Koden er: XXXX-XXXX-XXXX med den og de penge, der går ind på din foto.dk-konto lidt senere i dag vil du ende med et ganske fint tilbud."
#
# Det vil altså sige, at de kr. 194,- jeg har betalt for voucheren vil blive sat ind på min foto.dk-konto samt at jeg vil få 50% rabat. Jeg vil stadig komme af med penge for lærredsprintet, selvom de indrømmer at deres formulering var forkert.
#
# Mit svar til foto.dk: "Tak for svar. Jeg er lidt skuffet over at jeg nu skal betale et ekstra beløb, når I tidligere har oplyst mig at jeg kunne bruge koden den 15. april?"
#
# Foto.dk: "Jeg kan godt se det måske var lidt uklart formuleret at "du kan bruge den til d. 15. april" betød indtil d. 15. Derfor tilbød jeg dig en ny rabatkode."
#
# Jeg vil ikke betale yderligere for det store lærredsprint, så jeg bestiller derfor de tre små, hvor voucheren ikke er udløbet.
#
# De tre lærredsprint modtager jeg den 25. april, men da jeg åbner pakker er der kun to lærredsprint. Da jeg skal bruge alle tre lærredsprint den 27. april kontakter jeg straks kundeservice for at høre hvor det tredje billede er. Det kan de ikke oplyse mig om, men siger at det kan være det dukker op senere. Det skal lige siges, at jeg kun har modtaget ét trackingnummer og dette er på den forsendelse med de to lærredsprint, så sandsynligheden for at det tredje dukker op af sig selv, er ganske lille...
#
# Foto.dk skriver: "De sendes normalt samlet så du skulle modtage alle på én gang. Det kan være det er blevet adskilt fra de andre under transporten, men for en sikkerheds skyld bestiller jeg et nyt til dig med det samme. Skulle det oprindelige dukke op, så kan du blot beholde dem alle som et lille plaster på såret."
#
# Jeg oplyser dem om, at jeg skal bruge alle tre lærredsprint den 27. april, da de er af en hund der netop er død ganske uventet og jeg derfor har lovet børnene, at de kunne få et lærredsprint hver af hunden. Jeg spørger også hvad jeg skal sige til børnene, da jeg ved de vil blive knust over, at der er én der må undvære et billede af deres elskede hund. Foto.dk svarer blot, at de straks vil bestille et nyt lærredsprint. Jeg bliver på intet tidspunkt tilbudt nogen som helst form for kompensation!
#
# Jeg skriver til dem, at de burde lave et nyt lærredsprint med det samme og køre ud og aflevere til mig, da leveringsadressen er i samme by som de hører hjemme. Dette kan ikke lade sig gøre, da de bliver produceret i udlandet. Stadig ingen form for kompensation.
#
# Jeg kan efterfølgende se, at det manglende lærredsprint er bestilt den 27. april (og ikke den 25. april som lovet) og det er stadig ikke dukket op og det er i dag den 7. maj.
#
# Én ting er helt sikkert; jeg vil aldrig nogen sinde benytte foto.dk mere og de 194,- kr. der står min konto kan de bare slette!!!!
# Hurtig, nemt og sikkert. Enormt billige priser og virkelig hurtig levering. Kan desværre ikke give 5 stjerner, da pakken var stillet ved hoveddøren, selvom jeg havde sat kryds ved, at det måtte den ikke.
# Men vil helt sikkert handle her igen! :-) Mine bedste anbefalinger :-)
# Gennem mange år (ca. 50) har jeg været meget tilfreds med betjening og service hos såvel telefonpersonale som folkene i marken. - Enkelte undtagelser, hvor ventetiden har været for lang.
# 100 søbolde
# Jeg vil KLART anbefale alle at købe nailmania's geleprodukter, da jeg synes de er gode at arbejde med og er flotte!
#
# Priserne på produkterne er fine - dog synes jeg at et gebyr på 9,60 kr. ved betaling er lige lovlig dyrt nok.
#
# Hjemmesiden er okay - men kunne blive bedre i designet, og nemmere at finde rundt i (især ved bestillinger) :-)
# Jeg bestilte 9 liter olie om formiddagen. Dagen efter fik jeg pakken med min bestilling + 1 pose vingummi. Oplevede ingen problemer.
# Over et par uger forsvandt teksterne fra flere Viasat kanaler. Kundeservice fandt ud af at min fiberboks ikke havde været opdateret i over et halvt år. 10 minutter efter var alt opdateret, og alle tvkanaler fungerede upåklageligt. Meget behagelig kundeservice medarbejder at snakke med.
# At handle med 10-4 online er så nemt at det gør jeg gerne igen. Varen blev bestilt og fik oplyst der kunne gå op til 3 arbejdsdage, men allerede dagen efter kunne jeg afhente min varer. Hurtig og nem afhentning i butikken og da varen var betalt online kunne det ikke være nemmere.
# Bestilte varer  for en måned siden. De hævede pengene med det samme, har ikke fået mine varer. Har ringet 5 gange, i løbet af de sidste 3 uger, hvor de alle fem gange har sagt, at de sender varerne samme dag. Der sker bare ikke noget. Så pas på jeres penge, og køb jeres varer et andet sted.
# Bent Wagner Hansen
# Ringede fredag kl. 12.04 og spurgte om varen kunne være hos mig mandag, Send ordren igennem nu, så skal jeg nok tage den med det samme - varen lå i postboksen mandag - fantastisk.
# At så varen ikke er pakket i en pæn æske og udstråler den kvalitet som den burde er en anden ting.
# Jeg vil lige skrive og nævne at det er en fuser med det firma da jeg mødte firmaet på Scandinavian Motorshow i Bellacentret der blev der sagt at måtterne passede til vores biler Mercedes 300 med flippen til at hvile foden på for det var en betingelse som jeg sagde til dem, så det overbevidste sælger mig om at det var der, som for øvrigt er ejeren af shoppen selv,  jeg bestilte så sommer måtter og vintermåtter samt et garage overtræk og på hjemmesiden skriver de at det tager 3-5 dage for levering, der gik næsten 2 uger før jeg modt. en pakke, men der var kun sommer måtterne i ?, jeg ringede så til firmaet men der får man kun en sms besked tilbage om at de er optaget og man skal lægge en besked, men det ville jeg ikke finde mig i så jeg blev ved med at ringe til de tog den.
# Jeg spurgte så om hvor resten er varerne er henne og hvornår jeg så kunne forvente at modt. dem det vidste han ikke for jeg havde kun bestilt det jeg havde modt. det var sørens jeg gav ham ordre nr. hvor han så kunne se hvad det var jeg havde bestilt og igen var det ejeren selv jeg snakkede med.
# Men han havde ikke tid da han skulle til møde, det er det meste anvendelige salgs tricks der findes og så blev jeg vred på ham for pengene er hævet den dag jeg bestilte. og så passede måtterne ikke i formen som lovet og uden flip, lige pludselig sagde han at der nok ville komme en pakke mere på mandag og det er en uge siden og så ville han sende mig et Track & Trace. Nr. fra GLS pr. mail på resten senere på dagen men fik den aldrig så jeg skrev til ham dagen efter og jeg citere.
# Til [navn fjernet]
# Jeg har ikke modt. nogen mail fra dig vedr. Track & Trace. nr. på resten af min ordre som du lovede mig at sende, til mig i går hm.. jeg vil vide hvornår jeg får resten.
# Synes at det er noget være rod, det er da ikke nogen god reklame, du skal tænke på jeg reklamere for dig på min private webside.
#
# Og for det andet, de sommer måtter jeg har modt. det er jo ikke dem som du stod og sagde til os i Bellacenteret den gang, der sagde du at det var måtter med slip til at hvile foden på, for det var derfor jeg ikke har købt dem andre steder, " du sagde at det var der ", vi er jo flere der hørte hvad du sagde så der er ingen misforståelser der, så det er noget være plader du sagde til mig i telefonen at det kunne man ikke få, men det var måske kun et salgs tricks ? jeg synes at du skal være mere seriøs over for dine kunder.
#
# Ser frem til at få Track & Trace. nr. på de sidste to ting jeg mangler.
#
# Svar fra sælger
# Kære Carsten
# Jeg har ikke lovet dig slip på til foden, der er forskellige producenter af gummi måtter, og din er en ældre model så derfor kan det
# Være der lige netop ikke er til din model, beklager
#
# Angående pakkenummer har jeg lige overtaget en anden webshop så derfor haft lidt meget om ørerne sorry men det kommer her, GLS  pakkenummer 50683022491
#
# Med venlig hilsen/Best regards
#
#
# Der går så en uge mere hvor jeg skriver til ham igen:
#
# Til Heronline
# Att. [navn fjernet]
# Dit svar kan jeg ikke bruge til noget som helst vi var flere der hørte det, du er så useriøs og plat jeg har prøvet at ringe til dig flere gange vedr. min ordre .nr. 000529 jeg kan ikke se at GLS har modt. pakken med mine Gummimåtter da jeg bestilte ordren ville der gå 3 -5 dage nu er det over 14 dagen siden du fik ordren og jeg har stadig ikke modt. resten af ordren.
#
# Hvis jeg ikke modt. måtterne inden 3 dage så vil jeg have mine penge tilbage omgående og jeg vil skrive på de diverse medier om den måde du behandler dine kunder på samt i de diverse bil forummer om at de skal ikke købe hos dig jeg skriver det også på trustpilot hvor man skriver anmeldelser, men det ved du jo godt kan jeg se, det er jo ikke just de bedste anmeldelser du har der.
# Ps. Husk han har også over taget [ekstern reference fjernet] så pas på med at købe der også, så et godt råd spar pengene og irritationen over firmaerne Heronline/[ekstern reference fjernet]  for magen til dårlig service skal man lede længe efter!!! som de skriver de tidligere anmeldelser
# Vil lige nævne at jeg har fået pengene tilbage for Gummi måtterne. ved at true med bål og brand.
#
# Kære [navn fjernet]
#
# Du er da den største platugle sikke da noget fis du skriver som svar at jeg har fået gratis gummimåtter du er så fuld af løgn og ja jeg skriver til sidst at jeg fik pengene tilbage for gummimåtterne hvis du ellers kan læse efter at jeg har truet dig med bål og brand men jeg kan jo bare vedhæfte vores mailkorrespondance så kan folk selv bedømme det hvis det er, så endnu en gang vil jeg advare andre købere om dig og dit firma.
#
# Så stol ikke på den mand og for det andet kan man have mistanke om at han selv har skrevet de positive anmeldelser her på siden.
# Selv efter at have handlet på Black Friday gik der kun 2 hverdage til at jeg havde varen !
# Har brugt Elgiganten en del gange til erhverv indkøb, og flere gange er vores levering blevet forsinket grundet Elgigantens samarbejde med Bring. Det er naturligvis ikke Elgiganten, som ikke har formået at afsende vores varer rettidigt, men det er Elgigantens ansvar at entrere med et firma der kan håndtere leveringen. Senest har vi ventet en uge på levering af varer, og vil derfor fremtidigt foretage vores indkøb hos andre leverandører der har styr på deres distributions samarbejdspartnere
#
# opdateret 14/11-16 har vi stadigvæk ikke modtaget leveringen af den sidste pakke, ved kontakt til Elgigantens erhvervs kundeservice, hvor vi gjorde opmærksomme på forløbet, samt tilkendegivet vores utilfredshed med købet, fik vi at vide, vi blot skulle lade være med at modtage pakken, så ville vi få vores penge tilbage. Det er fint, vi er heller ikke længere interesseret i varen, men det var ikke derfor vi bestilte varerne i første omgang. Min anke er ikke på kvaliteten af Elgigantens varer, men et utilfredsstillende forløb omkring levering. Varerne er forsøgt afleveret kl. 19.17 samt kl. 21.27. Vi havde betalt 69,- for en erhvervslevering inde for tidsrummet 8-16. Vi har flere gange kontaktet Elgigantens kundeservice, men blot for at få at vide, at pakken sikkert kom samme dag. Denne anmeldelse på trustpilot er baseret på den manglende interesse i at få løst leveringsproblemerne, da det i vores optik er leverandørens ansvar at få de bestilte og betalte varer frem til kunden.
# Det en super service, jeg er specielt glad for at jeg nu kan finde adressen på folk med Navn- og adressebeskyttelse.
#
# Normalt er det jo kun noget det offentlige har adgang til, men takket være swipbox forside er det nu muligt for den almindelige forbrugere.
#
# Desværre er det dog begrænset af det kræver folk  har oprettet sig først - men man kan jo ikke forvente mere end det af en gratis adresse udleverings portal.
#
# En ting jeg dog mangler er CPR numre, men det kan der jo let skaffes i dag bare man har det fuldenavn og adresse.
#
# Oh right, 1 stjerne fordi de man vidst også kan sende pakker igennem dem.
# Jeg fik tilbud online om montering af ny forrude med elektrisk p-skive, og prisen lød på 1700 kr. Jeg tilvalgte også en Nano behandling til 99 kr når ny rude.
#
# Herefter bliver jeg på værkstedet, opkrævet afgift for klæbepuder til P-skiven og div andet så jeg samlet kommer af med 1875 Kr, imod de ellers aftalte 1700 plus 99 = 1799 Kr.
# Det er ikke beløbets størrelse (de 76 kr), men bare det at man ikke kan regne med et skriftligt tilbud.
#
# Det er bare ikke i orden Dansk Bilglas.
#
# Mvh Henrik
# Købte to nye tempur madrasser, da de gamle var blevet næsten 15 år gamle. Fik god rådgivning, god pris og fin fin service hvor butikken var gode til at ringe omkring leveringstid etc
# Jeg fik besøg af en reparatør på min bopæl,men det regnede,og selvom jeg havde etableret tørlæ,var manden ikke særlig motiveret for at lave skaden istedet skældte han mig ud,for at forholdene ikke var i top.han overtalte mig til at ringe til værkstedet. To uger efter ringede Carglass,og jeg lod mig overtale til endnu et besøg, blot med denbetingelse,at de ikke sendte den samme mand. Det gjorde de så. Jeg havde ikke den store tillid til ham.jeg ved ikke om det er lavet korrekt, for han var rimelig negativ,og gjorde et stort nummer ud af at udpensle hvad der kunne ske.det var ikke en rar oplevelse, og en grov tilsidesættelse af mit ønske. Firmaet må da have mere end en kørende rep. Så hvorfor sendte de så ikke en anden gang. Hvor svært kan det være.jeg har endnu en glasskabet på en 3 bil,men vedhelt ærligt ikke om jeg tør Carglass lave denne?
# oprettede en paypal, alt gik normalt indtil i dag hvor der hver time bliver trukket 1 krone.
# har fjernet mine kort derfra og krydser fingre for at det var enden.
# men gudhjælpende om de ikke også havde 22 kroner for gebyrer af en tilbage overførsel.
# aldrig brug det!!!!!!
# For anden gang har vi lejet et hotelophold gennem Feline. Feline fortjener de 5 stjerner for deres hurtighed.
# Uacceptabelt at jeg skal bøvle med, at få mine penge retur for en én uge gammel computer, der simpelthen ikke fungerede ordentligt. Efter lang  korrespondance hvor jeg prøver at få medarbejderen til at forstå, at jeg har min fulde ret til at få mine penge tilbage, kommer vi så til betalingen. Jeg fik af vide der HØJEST ville gå et par dage før pengene var på min konto. Over 2 uger efter har jeg stadig ikke set mine penge og det er simpelthen bare UACCEPTABELT. Tænk at man som kunde skal bruge tid og kræfter på ting, der burde være helt basale og forløbe sig smertefrit.
#
# Jeg kommer ikke og køber noget af jer længere
#
# Held og lykke til jeres næste kunder ...... Hvis de ikke også er blevet skræmt væk
# Jeg har købt en AEG blodtryksmåler hos Conrad Elektronik. Jeg har ikke handlet før hos CE, men har besluttet at købe varen der, da det var den billigste på markedet. Og det har jeg bestemt ikke fortrudt :) Ordren var registrerret og leveret fra Tyskland i løbet af to dage, Måleren er præcis og har en ekstra lang manchette (42 cm) Normalt skal man betale ekstra for denne, da de fleste blodtryksmålere leveres med manchetter i størrelse 36 cm. Od det kan lidt kraftigere mennesker ikke bruge.
# Jeg kan kun varmt anbefale handel hos Conrad Elektronik.
# 1,5 time forsinket i IC Lyn "1.klasse
# " ved Odense   uden reel forklaring og beklagelse. Nok hjemme kl 0130 i nat.
# Alt i alt en rigtig god oplevelse at handle på tøjbamsen.dk. Jeg bestilte mine varer den ene dag, og den næste dag var de klar til afhentning i min nærmeste Spar. Normalt foretrækker jeg at få varen sendt hjem, men den porto er simpelthen for dyr! Og 50 kr i porto for at få sendt en vare jeg selv skal hente i en butik synes jeg også er liiige i overkanten. Men handlede hos Tøjbamsen, da den ene top jeg købte var på tilbud. Desværre er str så mikro mikro, men jeg nægter simpelthen at bruge porto på at sende den retur PLUS at vedlægge yderligere 50 kr i porto for at få sendt en ny bluse retur.
# Så forsendelsesmæssigt er jeg skuffet, men ellers en god hjemmeside og hurtig levering
# Bestilte min vare og kunne afhente 1-2 dage efter, det kan man vidst ikke klage over !
# Hurtig handel, god hjemmeside. Lige til at finde det man har brug for så bare lækkert.
#
# Vil anbefale al småhandel her. Jeg bor i Fredericia ca 1 km fra xl-byg og alligevel var det her nemmere
# Kan kun anbefale man køber sine vare hos plantetorvet. Levering til tiden, og 70 flotte træer står nu i min have. Tak.
# 1. Jeg bestiller en ordre og forventer at pakken kommer inden for 5 dage, hvilket fremgår på deres hjemmeside. Efter 1 uge er pakken stadig ikke afsendt..
#
# 2. Deres grund er at deres leverandør ikke kan leverer det jeg har bestilt på deres hjemmeside, hvilket er underligt da jeg kun bestilte produkter som VAR på lager.
#
# 3. Jeg fortæller at hvis de ikke kan leverer alle mine produkter, vil jeg ikke modtage pakken, derefter fortæller hun at pakken netop er sendt afsted, så jeg skal bare lade være med at modtage pakken og den vil komme retur til dem.
#
# 4. Da jeg fortæller UPS at jeg ikke vil have pakken går der endnu en uge og tennis point modtager min pakke. Derefter får jeg en mail hvor der står at de vil refunderer prisen på mine produkter.
#
# 5. Syv dage efter, ringer jeg ind og spørger hvor mine penge er blevet af, en medarbejder fortæller at der er sket ENDNU en fejl og at hun vil sende dem i næste uge. Denne process har taget 4 uger indtil videre. UFATTELIG DÅRLIG SERVICE.
# Havde fået smadret glasset på min HTC Wildfire S, og kunne slet ikke bruge telefonen, så troede den var lige til at smide ud.
# Ringet til iExpert og fik at vide at jeg bare kunne kigge forbi, hvilket jeg gjorde. Reparationen tog ca 45 min (inkl lidt hygge snak), og kom ud derfra med en perfekt fungerende telefon.
# God service.
# Hurtig reparation.
# Og til en udmærket pris:-)
#
# H.L Randers
# Modtog pakken hurtigt.. 3 dage efter bestilling
# Måløs, men på den gode måde.
# Skulle i hast have en pakke til Idaho i USA. Blev afhentet på hjemmeadresse mandag eftermiddag. Natten mellem tirsdag og onsdag fik vi en sms om at den var fremme. Under 1½ døgn.  Sendt brev med post norden i tirsdags i sidste uge, de kom frem tirsdagen efter...  og de skulle i snit 20 km.  Så fuld respekt, og anbefaler meget gerne Pakke.dk. Også superlet med toldpapir etc.
# Min pakke var ankommet på posthuset d. 07-09-16. Modtog en mail om, at de havde forsøgt at levere min pakke, og at jeg snarest ville få en mail omkring hvor jeg kunne afhente pakken.
#
# 6 dage senere, havde jeg stadig ikke fået information om afhentning. Jeg gik på posthuset med mit pakkenummer, og pakken var slet ikke blevet skannet (som i at den ikke var ankommet). Øv.
#
# Anyways, så fik jeg min pakke til sidst, fordi jeg selv opsøgte post Danmark.
# Super hurtig levering og meget venlig betjening på Bygaden 23 i Sengeløse.
# Bestilte 2 covers, 2 skærmbeskyttere, 2 bilmontering kl. 15.30 fredag
# Levering med post dk dagen efter kl. 10.00... Flot.
# Jeg var overrasket over hvor billigt det var. Og leveringen var en af de hurtigste jeg har oplevet. Desuden synes jeg, det er en rigtig god service, man kan se, at hvis fx jeg bestiller inden 5 timer, så bliver pakken sendt samme dag. Thumbs up!
# God oplevelse! Det skab vi allerhelst ville have var ikke på lager og ville ikke komme hjem foreløbig. Blev vejledt til at købe et andet, som blev leveret efter 2 dage! Skabet lugter dog kraftigt!
# For det første findes der en postindleveringssted tættere på hvor jeg bor, pakken skulle have havnet der, ikke i Lyngby.
#
# Poststedet i Lyngby var underbemandet i forhold til antallet af folk der vil hente og indlevere pakker. Da jeg trak et nummer kunne jeg se at der var 35 foran mig i køen! Området kunne ikke rumme alle os der stod og ventede. Det tog 38 minutter at hente pakken! Det er alt for dårligt.
# Hurtig og tidlig levering kl 06:54
# Købte en grill i deres webshop men fandt den 400 billigere dagen efter i Bauhaus, så skrev til dem om at annullere orderen og det svarede de tilbage at det var gjort, 2 dage efter får jeg en mail om orderen er afsendt og modtager den den efterfølgende dag, så skulle til at indlevere grillen hos dem for at få pengene retur.
# Har aldrig hørt om Lomax før, dog er jeg positivt overrasket. De er det eneste firma som havde en bestemt vare på lager. Alle andre firmaer har ikke haft denne vare på lager i over 6 måneder eller mere
# Super fin service at de sender en mail hvor man kan sige hvor de må ligge pakken når man ikke er hjemme 👌🏻😊 Så slipper man for sedlen i papkasse med at man skal afhente den på posthuset mm. Jeg har været super tilfreds de sidste mange gange jeg har fået leveret pakker hos PostNord ! 😊👌🏻👍🏻 Så 5 stjerner fra mig 👏🏻
# Jeg kan kun medgive mine allerbedste anbefalinger til dette firma. Det bliver helt sikkert  ikke sidste gang jeg handler der. kh  Susanne
#
# Susanne Bødger
#
# 9900 Frederikshavn
# jeg er 13 år og jeg syndes den er sgu god det må jeg gi jer #Godpost
# Ganske enkelt det perfekte sted at købe sit udstyr. Jeg har ikke købt over hjemmesiden, da jeg bor 20 minutter fra butikken, men butikken er klart supergod.
# Havde brug for hjælp med nogle ridebukser, og selvom det tog noget tid, fandt vi lige det par det skulle være.
# Jeg er ALTID kommet ud af Unicorn med det jeg manglede, og har altid følt mig godt tilpas og så er der bare super service.
# Vi har bestilt et sofabord, vi bor 20 km fra nærmeste afhentningssted! Første gang jeg skal afhente, kommer der er ansat og ber mig om at kigge bordet efter for skrammer da de har haft nogle uheldige oplevelser med dem! Ganske rigtigt er det meget skammet!
# Anden gang er det det samme!
# Tredje gang ringer jeg inden, og denne gang er det intakt! Sender manden ind efter det som kommer hjem med to pakker! Det er bare to bordplader. Han kører ind igen for at bytte den defekte plade til bordben! For at få at vide at de ikke har dem.
# Heldigvis er de søde mennesker i kundeservice så rare at sende vores bordben med posten!
# Men jeg nu ikke sikker på at jeg vil købe gennem Coop igen! For meget besvær.
# Bestilte mine vare d 13/2-17.Skulle have haft mine vare d 18/2-17. og har ikke modtaget dem endnu d. 22/2-17
# Vi havde desværre indbrud medens vi var på ferie. Venlige naboer alarmerede politiet og fik huset lukket igen. Vi anmeldte vores forsikringskade fra feriestedet, og fik omgående tilbagemelding fra Topdanmark. Det videre forløb var rigtig godt, med besøg fra aftalepartneren Tønnes & Ulstrup for opmåling af beskadigede facadepartier, og en fantastisk dialog med en af selskabets medarbejdere. 14 dage efter hjemkomst var alt det forsikringsmæssige overstået og vi kunne lægge ubehagelighederne om indbruddet bag os.
# En dårlig oplevelse endte med en god oplevelse.
# Hilsen Ole P.
# 1. De er generalt bare billigst
#
# 2. Hurtig levering
#
# 3. Super hurtig og nyttig support
#
# Har handlet her flere gange, og søgt hjælp, og har altid fået en god behandling - Keep up the good work outlet.dk! :)
# Min 10år gamle Fiat Grande Punto i sort fik en polering og en gang coating og må sige at resultatet er mere end smukt. Den skinner som aldrig før og er samtidigt blevet 10 gange så let at holde ren og smuk. Kan kun anbefale Bilplejen.dk til alle der ønsker et professionelt stykke arbjde til penge der er til at betale.
#
# Fik også lavet mine alufælge der fulgte med til bilen og som var godt medtaget men også de står som næsten nye igen. Kunne man ligge et billede op så havde jeg gjort det.
#
# De er også gode til at rådgive og vejlede så man ikke føler at man bliver snydt og man kan mærke at de ligger en æresag i deres arbejde.
# Hej
# Det har været en supergod oplevelse at handle med Olisan på nettet.
# Bestilt søndag aften fra mit hjem i 8330 Beder.
# Modtaget af min søn i 3450 Allerød om tirsdagen.
# Det er bare super.
# Meget tilfreds
#
# Fik leveret min pakke i løbet af 1-2 dage uden problemer.
# De lyver åbenlyst over for deres kunder.
# Pakke nr: ymqrg44z.
# Jeg undrede mig efter 5 dage hvor min pakke blev af og ringede og fik af vide at den var sendt for 5 dage siden og at den vare jeg har bestilt i mellemtiden var blevet udsolgt og de derfor kunne sende en anden farve end den der var bestilt og efterlyse min pakke hvilket ville tag 14 dage at få svar på fra gls hvor den var.
# Jeg siger at jeg lige venter og ser om den dukker op og ringer så selv til gls og får af vide at den ikke er sendt men kun printet et labels ud.
# Jeg ringer så igen til vape4you som nu siger at den er sendt og de derdor nu har efterlyst pakken hos gls, jeg beder dem om at aflevere mine penge tilbage som de slet ikke burde ha trukket før pakken er modtaget og får af vide at der kan gå op til 3 hverdage.
# Jeg ringer så igen efrer en time til gls for at høre om oplysninger på pakkenr og de siger igen at den ikke er oberdraget til dem og bekræfter at pakken ikke er blevet efterlyst.
#
# Så i både lyver over for jeres kunder og sætter andre virksomheder i dårligt lys ved at give dem skylden, det er virkelig!!! dårlig! stil.
#
# I kunne bare ha været ærlige og sagt at det var udsolgt og først kom hjem om 14 dage og måske tilbyde at sende en aroma eller noget for ventetiden/tålmodighed så havede det ikke været noget problem.
# Overvej hvad i siger til jeres kunder før i begynder at lyve.
#
# Fint svaret men efter som gls har bekræftet at pakken ikke er efterlyst af jer hænger det ikke sammen.
# Og i burde ikke sætte andre firmaer i dårligt lys men selv tag ansvar for de fejl i laver...
# Alle kan se pakkenummeret og gå ind på gls's hjemmeside og se at den pakke aldrig er meldt savnet.
# Jeg er 200 % tilfreds. Jeg blev desværre forhindret i en rejse til Kina pga. sygdom, men Tryg forsikring var der med det samme og hjalp mig med det økonomiske. Kan ikke sætte en finger på noget ved Tryg forsikring :)
# Jeg fik min levering allerede 2 dage efter min bestilling.
# Og er meget tilfreds med mit produkt.
# Bestilt varer kl 11 torsdag, modtaget besked om at de er pakket kl 14 og til afhentning i pakkeboks næste formiddag kl 10.  Genialt koncept.
# Det var ok måske en dag hurtiger ,i følge foretningen blev det postet lørdag den 30/12-17 jeg modtog den 03/01-18.
# Hej.
# Jeg har haft meget ustabilt internet og tv siden starten af året ( langsomt internet siden jeg blev kunde for 4 år siden ). Sidst vi havde problemer med STOFA var i februar hvor vi gentagende gang mistede signalet og ringede 2 - 3 gange til teknisk afdeling - da de 3 medarbejdere ikke kunne forstå hvorfor vi ikke have noget signal, måtte vi jo tage en fridag så der kunne komme en tekniker på besøg. Det skal lige siges at vi også var nede i STOFA butikken i Århus og hente et nyt kabel for at tjekke at fejlen ikke lå hos os. 2 min efter teknikeren er kommet konstaterer han at i fra hovedkontoret har slukket for signalet, og han får det tilsluttet med det samme - SPILD AF EN FRIDAG! Tænk at 3 medarbejdere ikke kan se at signalet er slukket og de bare skulle slå det til igen! Det kostede os knap 1000 kr at afholde den fridag! I ”kompenserer” os med en måneds fri Bredbånds-abonnement og 4 filmleje.. Tak... for ca 10 dage siden konstaterede vi så igen at internettet og tv forbindelsen røg flere gange om dagen.. Jeg ringer så igen til jer og får at vide at det sikkert er vores kabler osv den er gal med, og min kæreste går så ned i STOFA butikken igen og får nye kabler og et nyt modem. MEN fejlen fortsætter og vi må have en tekniker ud. Det skal lige siges at i under alle disse opkald ”truer” med at vi skal betale de knap 1000 kr det koster at få en tekniker ud hvis fejlen er vores - altså hvis kablerne i lejligheden er i stykker eller hvis vi har tilsluttet noget forkert. I går fredag d.14/7 havde jeg så en tekniker ude som med det samme konstatere at kablet der sidder nede ved vejen i boksen er helt sort ( de kobber tråde der normalt skal være kobber farvet er sorte ) - han kaldte det vist en stikledning. Teknikeren ringer til jer og snakker med flere forskellgie for at finde ud af om vi selv skal betale for at få skiftet det kabel der går nede fra boksen ved vejen og ude langs bygningen op til 4 sal og ind til os - det får han at vide at vi selv skal betale for - 1500 kr! Hvordan kan det være at vi selv skal betale for det kabel som jeg formoder i har installeret for at jeg kan modtage den ydelse i sælger - nemlig internet og tv. Jeg kan godt forstå at jeg skal sørge for kablet inde i lejligheden, men mit abbonement starter vel i væggen? Jeg betaler knap 10.000 kr om året til jer for tv og internet, og den ydelse som i leverer fra stikket i væggen. Jeg kan da som privat person ikke vide noget om det kabel der sidder på ydermuren, som er det fra jeres side der gør at jeg kan betale jer 10.000 kr om året. Hvordan kan det være at jeg selv skal betale for at få det skiftet?  Jeg har boet her i over 4 år og nok betalt ca 40.000 kr til jer! Vi har altid haft mega langsomt internet, men i har flere gange sagt at det er fordi at der er mange der bor i området - hvorfor har i aldrig selv nævnt at det kunne være kablet på ydermuren!? Hvis det var blevet tjekket for længst, kunne vi have haft meget bedre internet. Jeg er så skuffet over den behandling/service vi har fået, og forventer at få svar på hvordan det kan være at vi skal betale for at få det kabel skiftet. Det er jo jer der leverer en ydelse som jeg kan betale for, ved at stikke et kabel i væggen. Jeg syntes at med den oplevelse vi har haft med STOFA, så er det på sin plads at i udskifter det kabel uden beregning - da vi har gjort alt for at sørge for at fejlen ikke lå hos os! Man kunne mistænke at i i princippet er ligeglade med jeres kunder, da i jo godt ved at i er den eneste leverandør i mit område, men jeg har simpelthen fået nok!
#
# PS.  Dertil står der på jeres hjemmeside: Kabeltræk netværkskabel op til 25 m  koster 850 kr. hvordan kan det så koste 1500 kr op til 4 sal???
#
# Hilsen Anne
# 2 timer var afsat - var ude at køre igen efter 1 time og 20 min efter forrudeskift.
# Moccamaster Kaffemaskine
# Fantastisk god kaffemaskine - drypstop - aut.slukning efter 40 min. Ellers ingen finesser - helt almindelig ordinær "gammeldags" kaffemaskine.
# Den er lydsvag og brygger en god kop kaffe.
# Kan varmt anbefales.
# MVH
# Lone
# Fandt vare og pris rimelig, tastede bestilling, var i tvivl om leveringstid, så skrev i kommentarfeltet om levering kunne gøres hurtig, som næsten straks blev besvaret og leveringen var inden 24 timer. Flot.
# Hvor blev TV2 sport a' ?
# Jeg skulle have leveret et lille brev i en pakkeboks. Men jeg endte alligevel med at få en sms fra Post Danmark hvor der stod at min pakke var for stor og derfor skulle hentes på et posthus 3 km væk.
# Tænk at man betaler en formue for så lidt ...
# Øv, jeg skal ikke handle mere på Coop.dk.
# Varerne kom for sent. Øget retur porto pga prisstigninger.
# Leveret på 2 forskellige måder, tilsyneladende fordi noget kom direkte fra leverandør.
# Man kunne ikke tillægge sin ordre endnu en vare. Måtte betale porto, selvom jeg havde handlet for over 1000kr
# Jeg kunne ikke gennemskue "servicen" med at betale 500kr for at få noget sendt retur.
# Men adskillige mails om, om jeg er tilfreds med leveringen, hmm, det kunne være jeg skulle svare den.
# Ikke gennemskueligt og træls
# Jeg købte min roomba 780 støvsuger ved Roboteksperten.dk. Prisen her var billig i forhold til konkurrenterne, som i øvrigt ikke heller ikke var i stand til at levere støvsugeren ligeså hurtigt.
#
# Støvsugeren gør hvad den skal og når men giver den de rette betingelser kommer den faktisk bedre rundt i kanter og under møblerne end man selv ville have gjort ved daglig støvsugning. Vi har 2 hunde! Støvsugeren har kørt adskillige gange og børsterne er stadig rene, så udover at tømme støvbeholderen har vi minimal vedligehold på den.
#
# Støvsugeren blev bestilt i påsken og blev leveret 2. hverdag efter påsken hvilket svarer til dag til dag levering.
#
# Meget tilfredsstillende!
# Bestilte et par sko omkring kl 16:30 og kunne allerede hente skoene næste formiddag :)
# Super hurtig levering og de bestilte varer lever op til forventningerne.
# Det eneste der er træls er,  at man skal købe for mange penge for at få gratis fragt. Derfor 4 stjerner.
# Bestilte 3 varer, hvoraf de to kom problemfrit,  medens den tredie blev sendt til en forkert adresse. Men det blev løst tilfredsstillende.
# Jeg bestilte pære til min bil, både til nummerplade lys og til bagagerum.
# De leverede nummerplade lys viste sig at være i to forskellige farver (den ene hvid og den anden med en smule grøn i). Disse fik jeg ombyttet uden yderligere.
#
# Efterfølgende har jeg lagt mærke til at nummerplade lyset blinker ret kraftigt, når bilen er kører, men ikke når den holder stille med tænding på. (dette er svært at vurdere, om de altid har gjort dette, da jeg ikke selv ser bilen udefra).
#
# Jeg har efter dette blev konstateret skrevet 3 mails, uden svar nogen former for svar.
# Deres app virker åbenbart ikke til bestilling, så jeg troede de kom om mandagen, men så ringer de og spørger om jeg har fået det lavet... øh nej, nå men så kan du få en tid torsdag i dit område.. ok! Men han manden fra Carglass var virkelig super hurtig, dygtig og venlig, så 4 stjerner til ham🤗
# Jeg har været inde og få massage 15+ gange og er lige fantastisk hver gang! Kan ikke andet end at anbefale det!
# ...
# Jeg bestilt 128 GB SD kort til min nye Samsung S7 Edge kl 15:50.
# Fik den dagen efter sammen med posten :-)
# Post nord skriver til mig, at de prøvede at aflevere pakken på min add. fredag kl.14.32.  Passer ikke, der var jeg hjemme.
#
#
#     Mvh. Birgitte.
# Jeg bestilte mine varer inden klokken 14, og modtog dem dagen efter. Det var perfekt og nemt! 😊
# Egentligt en fin handel, hurtigt og smertefrit, synes dog det er åger at forlange 65 kr. i ekspeditionsomkostninger
# Jeg er især godt tilfreds med 3 like home. Her har 3 virkelig været forrest.
# Jeg har haft en del citroen biler, her under et par berlingoer.
# Har altid købt nye biler for at slippe for det store bøvl, da man jo har garanti på sin bil.
# Dog må jeg desværre give citroen en dårlig anmeldelse da jeg efter mere en 6 måneder efter jeg har købt min bil, forsat har software fejl på bilen.
# Værkstedet har gjort hvad de kunne de første par måneder uden held og måtte komme frem til den konklusion at de ikke kunne gøre mere for mig nu.
# De udtaler at fejlen er på alle modeller af min bil (Berlingo 2016 1.6 benzin)og man kun kan afvente at citroen retter fejlen.
# Det jeg så ikke fatter er hvordan kan man sælge biler til sine kunder uden at informere dem om at der er en fejl fra starten af ?
# Min bil model har været solgt flere måneder før jeg købte min, så fejlen må man jo have vidst ville komme på min model også.
# Min Citroen forhandler var ikke klar over det, da de selv brugte en del tid i starten på at prøve at udbedre fejlen.
# Jeg lader tvivlen kommer dem til gode.
# Det er klart en ommer og en dårlig oplevelse når man køber ny bil.
# Havde jeg vidst at fejlen var på vognen fra starten af havde jeg valgt en anden model.
# Så i øjeblikket kan jeg ikke anbefale mærket citroen når der er nogle der spørger, lidt trist oplevelse efter mange år med dette bil mærke.
# Ellers en dejlig bil.....
# Informere jeres kunder hvis i levere fejlbehæftet biler, selv om det kan betyde at de vælger en anden model eller mærke.
# Svaret jeg har fået fra Citroen er at jeg bare må have tålmodighed, der vil på et eller andet tidspunkt kommer en software opdatering.
# Fra start til slut har det været en god oplevelse at handle med jysk diner.
# Jeg har kun roser tilovers, servicen i telefonen, nemheden ved levering, eller den lækre mad! Og der var rigelige mængder! Kan kun anbefales herfra.
# 5 stjerner :)
# Vi bestiller igen i det nye år!
# Bestilte lidt i 17 havde allerede pakken næste dag før middag :) se det er hurtig.. :) bestiller gerne der igen
# Har kun handlet hos haven4kids en enkelt gang, men det er gået super. Hurtig problemfri handel og levering, så intet at komme efter:)
# Er yderst tilfreds.
# Hej,
# Jeg bestilte en rejse Søndag 26/06/17 , til London Gatwick fra den 29/06-4/06/17 hvor jeg efterfølgende fik e-mail om at jeg ville få en bekræftelse inden for 24 timer.
# Nu er det onsdag 28/06, og der er gået langt over 24 timer. Når jeg prøver at tjekke på jeres hjemmeside, har der nu i 2 dage stået at jeg får svar samme dag.
#
# Da jeg skal rejse imorgen tidligt ( og min rejse er ikke bekræftet endnu!) burde jeg have fået svar. jeg har nu ikke mulighed for at booke med et andet selvskab, da billetterne er blevet alt for dyre dagen før. Jeg ved ikke om det skal forståes sådan at jeg er bekræftet på min rejse imorgen ( som e-mailen indikere og det kun er hjemrejsen der mangler at blive bekræftet?). Jeg er meget utilfreds med denne behandling, og kan, på baggrund af dette, ikke anbefale travellink.com og er stadig usikker på om jeg kommer på min rejse imorgentidlig. Hvorfor overholder i ikke jeres egene tidbegrandsniger ?
#
# Rettelse:
# Jeg har nu talt med Sofia fra Travellink, som fik set på fejlen og ombooket mig, sådan at jeg kommer afsted imorgen, som planlagt. Tak for hjælpen Sofia.
# hilsen
# N. Christensen
# Findes det kan man finde det på Google.dk
# De får kun 4 stjerner af mig pga af Google Desktop. Det var en gang verdens bedste produkt .. Men nu har de ødelagt den af. Den finder ikke tingene mere og den er ustabil :(
#
# Desværre fordi jeg savner produktet.
# Vi flyttede til ny ejerbolig, og ejendomsmægleren sørgede for at meddele ejerskifte og alle relevante oplysninger til DONG's kundeservice pr. e-mail dagen efter.
# 2½ uge efter modtager vi pr. post en meddelelse om, at DONG endnu ikke har registreret en ny beboer, og beder mig udfylde et kort, som jeg skal påføre frimærke og sende med posten.
# Det forekommer urimeligt, at jeg skal have denne ulejlighed og udgift, når oplysningerne en gang er sendt til DONG. Jeg kan da ikke gøre for, at DONG's kundeservice endnu ikke er nået til at ekspedere den e-mail som en gang var fremsendt. Og hvem ved om dette kort når frem og modtages korrekt?
# Jeg har nu været on/off kunde hos web10 i flere år. Det sidste års tid dog mere seriøst, med en reel forretning (webshop). Vi har kun oplevet meget korte nedbrud, og efterfølgende fået det løst meget hurtigt. Supporten er som regel venlige, og hurtige til at svare.
#
# Vi har dog problemer med hastigheden af vores side, hvilket vi har snakket med en medarbejder omkring. Han har fået sat en tekniker på sagen, og det virker umiddelbart som om de gør meget for kunderne og for at yde en god service. Medarbejderne ved hvad de snakker om, og giver kvalificeret support.
#
# Jeg synes ikke det er helt fair, at web10 har fået så dårlige anmeldelser her på trustpilot. De er gode til prisen, og de yder god service.
# Super hurtigt og effektivt. Fik mail + sms og samme dag kunne jeg smutte forbi Fakta og hente pakken i Post DK automaten. Der er åbent helt til kl. 22 og anvisningen fra Post DK var nem at følge.
# Tøjet blev afhentet og afleveret i det aftalte tidsrum og jakkesættene blev fine. Hvis de skal have 5 stjerner, så skal alle folderne på jakkesættene være rigtige og tidsrum for afhentning/aflevering være kortere.
# Og det er kun blevet nemmere, dejlig pædagogisk hjemmeside og god kvalitet varer. Vi har 1 gardin ud af alle dem vi har købt igennem årene hvor snoretrækket er gået i stykker. Det er faktisk godt gået men jeg skriver lige og hører om jeg kan købe et nyt optræk til det en af dagene 🇩🇰😇🇩🇰😇
# Jeg har brugt Just-eat igennem mange år nu, og jeg er mere end tilfreds. Hvis noget går galt med levering og andet, så er kundeservice mere end glade for at hjælpe, og de få gange hvor levering ikke har været muligt, har jeg fået pengene pænt leveret tilbage. :)
#
# Jeg har givet 5 stjerner, selvom just-eat har haft sine fejl, men de er til at overse, og de har forbedret sig meget gennem årene.
#
# Så de har helt klart fortjent alle 5 stjerner. :)
# Jeg lejede en container i 4 måneder uden nogen problemer.
# Jeg ringede flere gange om at ændre i datoen for hvornår den skulle hentes og hver gang fik jeg en fin behandling. Også da jeg skulle have den afhentet med 1 dags varsel. Fantastisk koncept :)
# Indtil videre har det kun været en god oplevelse. Vi har sparet 2700,- på vores bilforsikring og oveni købet fået et gavekort, for at skifte.
# Modtog besked om at varen var ankommet i løbet af tre dage.
# I pakken lå 2stk. Chokolade
# Hvis det var muligt ville jeg give 6 stjerner. Har købt en virkelig fin computer til en fornuftig pris. Samtidig en venlig og kompetent rådgivning. Alt i alt, det hele er super.
# Bent R.
# Bestilte et Suunto pulsur til en god pris og havde det i hånden mindre end 48 timer efter. Super god service.
# Jeg tænker på at skifte forsikringsselskab og har derfor henvendt mig til ALKA. Oprindelig p.g.a. annonceringen "Vi vasker din bil"
# Jeg har fået et attraktivt tilbud og er næsten sikker på, at jeg skifter til ALKA - også på grund af den venlige betjening jeg fik, da jeg ringede på det velkendte nummer: 70121416
# Med venlig hilsen Winnie
# Jeg har ikke en finger at sætte på deres service, pris eller kvalitet - Bestilte et kors i guld til en god pris og havde det inden for 24 timer - Så ingen klager herfra ☆☆☆☆☆
#
# Mvh Kim
# Hvis man bestiller varer fra firmaer, der benytter PostNord, så oplever vi ingen problemer. Meeen drejer det sig om de breve vi har sendt og modtaget, så halter det gevaldigt i forhold til jeres Q-post med dag til dag levering. 26 takkekort efter vores bryllup sidste år blev afsendt med Q-post. Lidt besværligt var det, ekspedienten var ikke helt klar over hvordan det fungerede, men jeg havde læst på lektien hjemmefra, så frimærker og store stregkoder på mine små kuverter, og så afsted med dem. Det undrede os, at vi ikke hørte noget fra nogen, men efter 4 dage begyndte meldingerne at tikke ind, og nysgerrige begyndte vi at spørge til hvornår de var modtaget... mellem 4-6 dage var det mest almindelige. Den sidste modtog vores takkekort efter 10 dage! Helt ærligt, 4-10 dage med Q-post, det er dæleme ikke i orden, når man vælger at betale for dag til dag levering.
# Så jeg er desværre ikke længere flittig kunde hos jer, det blev simpelthen for meget af det gode!
# Desværre må jeg skrive dette da jeg ellers er tilfreds med at træne i Fitness World.
#
# Det kan ikke være rigtigt at man ikke kan få svar når man ringer ang problemer med regninger og blive via telefon sluse henvist til centeret hvor man træner.
# Når man så taler med personalet ved de intet og kan intet gøre ved evt fejl så kan man bare lade sig snyde hvis der er blevet trukket beløb ved en fejl.
# Hasr nu været medlem en del og år og har ca 3000 kr til gode som er trukket ved fejl og har intet modtaget dette er tyveri.
# Elendig forhandler, som trækker 89 kr fra min konto hver måned pga et medlemskab, som jeg aldrig har godkendt. Min toastmaskine endte med at koste mig 600 kr, fordi jeg først opdagede mit dyre medlemskab efter 5 måneder. Den kostede 100 kr på deres hjemmeside. Jeg melder dem nu til konkurrence- og Forbrugerstyrelsen!
# der er service hele vejen igennem hvorfor har i kun op til 5 stjerner
# jeg vil gerne give jer 10-15
# For 7 uger siden bestilte jeg en vinduespolering gennem Sweetdeal og da jeg skulle bestille en tid hos Perfectly Clean var jeg i telefonisk kontakt med en medarbejder, som sagde, at det var nemmest at jeg gjorde det via deres hjemmeside og selvom jeg allerede havde betalt skulle jeg bare indtaste mine kortoplysninger, der ville ikke blive trukket penge for købet når jeg allerede havde betalt, sagde han.
# Der blev naturligvis trukket penge på mit betalingskort, som Perfectly Clean lovede, at refundere, men 7 uger efter har jeg ikke set en krone og jeg har nu kontaktet dem 4 gange. 3 gange pr. mail og 1 gang pr. telefon hvor der blev lagt på.
#
# Det er derfor sikkert, at sige jeg ikke vil benytte Perfectly Clean igen da det er den dyreste vinduespudsning jeg nogensinde kommer til, at få.
# Jeg skulle bestille 15 flasker grøn Sourz likør, som skulle bruges til en fest en uge efter.  Eftersom det var mange flasker og jeg skulle bestille over nettet havde jeg store betænkeligheder ved at gøre det med den korte tidsfrist da de højest sandsynligvis ikke havde så mange flasker på lager. Derfor ringede jeg til dem for at forhøre mig hvor jeg blev lovet en dato de ville komme på lager hvis jeg bestilte, og jeg blev lovet at de ville være leveret ved min hoveddør dagen efter. Det hele forløb som aftalt via telefonen, dog ringede jeg den dag de fik dem på lager for lige at sikre mig at de rent faktisk var kommet, men det kunne jeg godt have sparet mig. De stod foran min dør dagen efter helt perfekt :)
# Min integrerede Siemens opvaskemaskine var gået i stykker og jeg bestilte et servicebesøg hos Bosch Siemens Gaggenau Hvidevareservice BSH Hvidevarer A/S. Jeg var ikke selv hjemme da serviceteknikeren kom på besøg men jeg har fået fortalt at han var til stede i ca. 2 minutter. Efterfølgende kommer der en regning på 595 kroner.
# Beskeden på girokortet lyder:
# "Maskine kan ikke udtages, nyt gulv er lagt oven på ben. Ingen fejlsøgning mulig. Maskine er 10 år gammel. Hvis det er vandindtag koster det 3600.-"
# Mit indtryk er, at serviceteknikeren giver op alt for let. Han er tilsyneladende ikke opgaven voksen.
# Jeg kontakter efterfølgende en konkurrent til Siemens Hvidevareservice og han kan uden problemer lave maskinen for 1497 kroner.
# Det er langt bedre at få løst problemet for 1497 kroner end at betale 595 kroner for ikke at få løst problemet.
# Med venlig hilsen
# Har vært i tdc i 2  år nu og der er film fra da jeg startede få dem nu skifte ud i skal ikke kom og sige af folk er vild med dem i  nu :)
# REDIGERET: Jeg skrev en ny anmeldelse med det samme indhold. Denne gang offentliggjorde elgigannten den på deres hjemmeside. Derfor er det rettet til 3 stjerner. Men det ændrer selvfølgelig ikke på den første oplevelse. Jeg ville jo blot "advare" folk mod leveringen. Jeg foretrækker til en hver tid PostDanmark
#
# Een stjerne er måske at stramme den. Men når man lægger en posistiv bedømmelse på elgigantens hjemmeside, fordi man har haft en god oplevelse mht. køb og service (og heldigvis overvejer de positive oplevelser i det firma) så tager de imod med kyshånd. Men når man har en berettiget kritik, så får man blot følgende standardmeddelelse:
#
# "Din anmeldelse er blevet modereret
# Vores medarbejdere har læst din anmeldelse og værdsætter dit bidrag, selvom det ikke følger alle vores retningslinjer. Tak, fordi du delte det med os. Vi håber, at vi offentliggør dit bidrag næste gang!"
#
# Det er simpelthen for ringe! de må sgu tage det sure med det søde. Derfor får de dumpekarakter her.
#
# Det jeg brokkede mig over var, at de brugte GLS til at levere film, når nu de bruger PostDanmark til alt andet. Posten kommer frem eller kan afhentes i den lokale Postbutik. Hvorimod GLS tager pakker med tilbage til Kolding, selvom man har investeret i en pakkepostkasse. Man skal så ringe og få pakken bragt ud til en lille Brugs på bøhlandet, som tilfældigvis er GLS-pakkeshop.
# Egentlig er det jo GLS, der har den dårlige service, men det er elgiganten, der vælger GLS som leverandør, og derfor må leve med kritikken. Men jeg er meget uforstående over for at den bedømmelse ikke "følger deres retningslinier"... står der i retningslinierne, at kritik skal være positiv?

# %%
import explore_regex as e_re
# %matplotlib inline

# %%
# money example
#explore_money = ExploreRegex(sample_string)
explore_money = e_re.ExploreRegex(sample_string)
first = 'kr'
second = '[0-9]+kr'
third = '[0-9]+(?:[,.][0-9]+)?kr'
fourth = '[0-9]+(?:[,.][0-9]+)?\s{0,2}kr'
final = '[0-9]+(?:[,.][0-9]+)?\s{0,5}kr(?:oner)?'
patterns = [first,second,third,fourth,final]
for pattern in patterns:
    explore_money.explore_difference(pattern,patterns[0])
explore_money.explore_pattern(second)
# Out:
# ------ Pattern: kr	 Matched 1069 patterns -----
# Found 0 overlaps between the expressions:
#         pattern1: kr 	 and
#         pattern2: kr
#         1069 included in pattern1 and not in the pattern2
#         1069 was included in pattern2 and not in pattern1
# ------ Pattern: [0-9]+kr	 Matched 83 patterns -----
# Found 166 overlaps between the expressions:
#         pattern1: [0-9]+kr 	 and
#         pattern2: kr
#         0 included in pattern1 and not in the pattern2
#         986 was included in pattern2 and not in pattern1
# ------ Pattern: [0-9]+(?:[,.][0-9]+)?kr	 Matched 83 patterns -----
# Found 166 overlaps between the expressions:
#         pattern1: [0-9]+(?:[,.][0-9]+)?kr 	 and
#         pattern2: kr
#         0 included in pattern1 and not in the pattern2
#         986 was included in pattern2 and not in pattern1
# ------ Pattern: [0-9]+(?:[,.][0-9]+)?\s{0,2}kr	 Matched 341 patterns -----
# Found 682 overlaps between the expressions:
#         pattern1: [0-9]+(?:[,.][0-9]+)?\s{0,2}kr 	 and
#         pattern2: kr
#         0 included in pattern1 and not in the pattern2
#         728 was included in pattern2 and not in pattern1
# ------ Pattern: [0-9]+(?:[,.][0-9]+)?\s{0,5}kr(?:oner)?	 Matched 341 patterns -----
# Found 682 overlaps between the expressions:
#         pattern1: [0-9]+(?:[,.][0-9]+)?\s{0,5}kr(?:oner)? 	 and
#         pattern2: kr
#         0 included in pattern1 and not in the pattern2
#         728 was included in pattern2 and not in pattern1
# Match: 356kr	Context:pr måned (356kr!) fra min
# Match: 49kr	Context:ndbetales 49kr under lov
# Match: 6000kr	Context:siden til 6000kr men deres
# Match: 180kr	Context:eg af med 180kr mere??
#
# C
# Match: 2500kr	Context:ris på ca 2500kr. Jeg godt
# Match: 5000kr	Context:ert brugt 5000kr på jeres
# Match: 500kr	Context: for over 500kr  jeg købt
# Match: 689kr	Context:varer for 689kr-desværre
# Match: 2777kr	Context: får mine 2777kr tilbage f
# Match: 500kr	Context:ebyr på 3-500kr for en pe

# %%
explore_money.report('soft')
# Out:
# ------ Pattern: kr	 Matched 1069 patterns -----
# ------ Pattern: [0-9]+kr	 Matched 83 patterns -----
# ------ Pattern: [0-9]+(?:[,.][0-9]+)?kr	 Matched 83 patterns -----
# ------ Pattern: [0-9]+(?:[,.][0-9]+)?\s{0,2}kr	 Matched 341 patterns -----
# ------ Pattern: [0-9]+(?:[,.][0-9]+)?\s{0,5}kr(?:oner)?	 Matched 341 patterns -----

# %%
explore_money.report('hard')
# Out:
# ------ Pattern: kr	 Matched 1069 patterns -----
# ------ Pattern: [0-9]+kr	 Matched 83 patterns -----
# ------ Pattern: [0-9]+(?:[,.][0-9]+)?kr	 Matched 83 patterns -----
# ------ Pattern: [0-9]+(?:[,.][0-9]+)?\s{0,2}kr	 Matched 341 patterns -----
# ------ Pattern: [0-9]+(?:[,.][0-9]+)?\s{0,5}kr(?:oner)?	 Matched 341 patterns -----

# %%
print(explore_money.patterns[3],explore_money.patterns[4])
explore_money.explore_difference(explore_money.patterns[3],explore_money.patterns[4])
# Out:
# [0-9]+(?:[,.][0-9]+)?\s{0,2}kr [0-9]+(?:[,.][0-9]+)?\s{0,5}kr(?:oner)?
# Found 682 overlaps between the expressions:
#         pattern1: [0-9]+(?:[,.][0-9]+)?\s{0,2}kr 	 and
#         pattern2: [0-9]+(?:[,.][0-9]+)?\s{0,5}kr(?:oner)?
#         0 included in pattern1 and not in the pattern2
#         0 was included in pattern2 and not in pattern1
# ([], [])
